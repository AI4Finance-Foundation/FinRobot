# %% [markdown]
# ## HIERARCHICAL FUNCTION CALLING AGENT FOR OPENBB

# %%
# !git clone https://github.com/Athe-kunal/openbb-agent.git

# %%
import os

os.chdir("openbb-agent")

# %% [markdown]
# ## PROVIDE YOUR OPENAI API KEY AND OPENBB PERSONAL ACCESS TOKEN (PAT)
#
# You can fill in your API keys from different financial providers in OpenBB by logging into your OpenBB platform and filling in the API keys for each provider. Then you can generate a PAT token to login to OpenBB

# %%
# %%writefile .env
# OPENAI_API_KEY=""
# OBB_PAT=""

# %%
from agent.dspy_obb_agent import DSPYOpenBBAgent
from dotenv import load_dotenv,find_dotenv
from agent.database import load_database, build_database, build_docs_metadata
from agent.dspy_agent import OpenBBAgentChroma
import os 

# %load_ext autoreload
# %autoreload 2

load_dotenv(find_dotenv(),override=True)
# Out:
# True

# %% [markdown]
# ## BUILDING THE DATABASE

# %%
from agent.database import build_graph

router_names_graph,router_names = build_graph()

# %% [markdown]
# ## REASONING BEHIND HIERARCHICAL FUNCTION CALLING
#
# 1. Function discovery or relevant tool discovery is essential in function calling. The current method includes similarity matching with the function descriptions and picking 3-4 functions.
# 2. But in hierarchical function calling, we can divide the functions into hierarchical graphs, as you can view below. Each graph has a parent node and the leaf nodes are the functions from different providers in OpenBB
# 3. We can traverse the graph by passing the descriptions of the current level nodes, and use an LLM to pick the node to jump to. Hence, we can narrow down the search space of these functions and break down the problem

# %%
from networkx.drawing.nx_agraph import graphviz_layout
import matplotlib.pyplot as plt
import networkx as nx

for router in router_names:
    graph = router_names_graph[router]
    pos = graphviz_layout(graph, prog="dot")
    plt.figure(figsize=(20, 10))
    nx.draw(graph, pos, with_labels=True, node_size=500, node_color="skyblue", font_size=5, font_weight="bold", arrows=True)
    plt.title(f"{router.upper()}")
    plt.show()

# %% [markdown]
# ## TO BUILD THE DATABASE, UNCOMMENT THE BELOW LINES AND RUN THEM

# %%
# from agent import build_docs_metadata

# docs,metadata = build_docs_metadata(router_names_graph)
# build_database(docs,metadata,os.environ['OPENAI_API_KEY'])

# %%
openbb_collection = load_database(os.environ['OPENAI_API_KEY'])
obb_chroma = OpenBBAgentChroma(openbb_collection) 
dspy_obb = DSPYOpenBBAgent(obb_chroma)

# %%
from openbb import obb
# Login to OpenBB and prefer dataframe outputs
obb.account.login(pat=os.environ['OBB_PAT'])

obb.user.preferences.output_type = "dataframe"

# %% [markdown]
# ## IN THE BELOW EXAMPLE YOU CAN SEE HIERARCHICAL FUNCTION CALLING IN ACTION
#
# 1. First the parent levels equity, etf etc. are passed to LLM, and the LLM answers rightly that it needs equity node to answer this question.
# 2. Now, we will compare only the functions inside the equity node. After that there are multiple options like `screener`, `estimates` etc, and the LLM picks fundamental.
# 3. The graph iteratively builds to the right function and then we call it to get the results.

# %%
output = dspy_obb("Is tesla overvalued?")

print(output)
# Out:
# First level string: equity: Get historical and upcoming initial public offerings (IPOs). Get historical and upcoming dividend payments. Includes dividend amount, ex-dividend and payment dates. Get historical and upcoming stock split operations. Get historical and upcoming company earnings releases. Includes earnings per share (EPS) and revenue data. Get the closest peers for a given company.  Peers consist of companies trading on the same exchange, operating within the same sector and with comparable market capitalizations. Copmare reported company facts and fundamental data points. Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates. Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements. Get equity valuation multiples for a given company. Get the balance sheet for a given company. Get the growth of a company's balance sheet items over time. Get the cash flow statement for a given company. Get financial statements as reported by the company. Get the growth of a company's cash flow statement items over time. Get historical dividend data for a given company. Get historical earnings per share data for a given company. Get historical employee count data for a given company. Search Intrinio data tags to search in latest or historical attributes. Get the latest value of a data tag from Intrinio. Get the historical values of a data tag from Intrinio. Get the income statement for a given company. Get the growth of a company's income statement items over time. Get fundamental metrics for a given company. Get executive management team data for a given company. Get executive management team compensation for a given company over time. Get an extensive set of financial and accounting ratios for a given company over time. Get the revenue geographic breakdown for a given company over time. Get the revenue breakdown by business segment for a given company over time. Get historical stock splits for a given company. Get earnings call transcripts for a given company. Get the 1 year trailing dividend yield for a given company over time. Get data about major holders for a given company over time. Get data about institutional ownership for a given company over time.
#
# etf: Search for ETFs.  An empty query returns the full list of ETFs from the provider. ETF Historical Market Price. ETF Information Overview. ETF Sector weighting. ETF Country weighting. Price performance as a return, over different periods. Get the holdings for an individual ETF. Use this function to get the holdings dates, if available. Get the exposure to ETFs for a specific stock.
#
# fixedincome: Treasury Constant Maturity.  Get data for 10-Year Treasury Constant Maturity Minus Selected Treasury Constant Maturity. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities.Select Treasury Constant Maturity.  Get data for Selected Treasury Constant Maturity Minus Federal Funds Rate Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Select Treasury Bill.  Get Selected Treasury Bill Minus Federal Funds Rate. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Get yield curve data by country and date. Government Treasury Rates. ICE BofA US Corporate Bond Indices.  The ICE BofA US Corporate Index tracks the performance of US dollar denominated investment grade corporate debt publicly issued in the US domestic market. Qualifying securities must have an investment grade rating (based on an average of Moody’s, S&P and Fitch), at least 18 months to final maturity at the time of issuance, at least one year remaining term to final maturity as of the rebalance date, a fixed coupon schedule and a minimum amount outstanding of $250 million. The ICE BofA US Corporate Index is a component of the US Corporate Master Index. Moody Corporate Bond Index.  Moody's Aaa and Baa are investment bonds that acts as an index of the performance of all bonds given an Aaa or Baa rating by Moody's Investors Service respectively. These corporate bonds often are used in macroeconomics as an alternative to the federal ten-year Treasury Bill as an indicator of the interest rate. High Quality Market Corporate Bond.  The HQM yield curve represents the high quality corporate bond market, i.e., corporate bonds rated AAA, AA, or A.  The HQM curve contains two regression terms. These terms are adjustment factors that blend AAA, AA, and A bonds into a single HQM yield curve that is the market-weighted average (MWA) quality of high quality bonds. Spot Rates.  The spot rates for any maturity is the yield on a bond that provides a single payment at that maturity. This is a zero coupon bond. Because each spot rate pertains to a single cashflow, it is the relevant interest rate concept for discounting a pension liability at the same maturity.
#
# derivatives: Get the complete options chain for a ticker. Historical futures prices. Futures Term Structure, current or historical.
#
# crypto: Get historical price data for cryptocurrency pair(s) within a provider. Search available cryptocurrency pairs within a provider.
#
#
# First level answer: equity
# Current Trail: ['equity'] and level: 2
# Subsequent level 2 string to LLM: screener: Screen for companies meeting various criteria.  These criteria include market cap, price, beta, volume, and dividend yield.
#
# estimates: Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates.
#
# market_snapshots: Get an updated equity market snapshot. This includes price data for thousands of stocks.
#
# discovery: Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements.
#
# fundamental: Get equity valuation multiples for a given company. Get the balance sheet for a given company. Get the growth of a company's balance sheet items over time. Get the cash flow statement for a given company. Get financial statements as reported by the company. Get the growth of a company's cash flow statement items over time. Get historical dividend data for a given company. Get historical earnings per share data for a given company. Get historical employee count data for a given company. Search Intrinio data tags to search in latest or historical attributes. Get the latest value of a data tag from Intrinio. Get the historical values of a data tag from Intrinio. Get the income statement for a given company. Get the growth of a company's income statement items over time. Get fundamental metrics for a given company. Get executive management team data for a given company. Get executive management team compensation for a given company over time. Get an extensive set of financial and accounting ratios for a given company over time. Get the revenue geographic breakdown for a given company over time. Get the revenue breakdown by business segment for a given company over time. Get historical stock splits for a given company. Get earnings call transcripts for a given company. Get the 1 year trailing dividend yield for a given company over time.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for information related to the valuation of a company, specifically Tesla in this case.',
#     output='fundamental'
# )
# Current Trail: ['equity-->fundamental'] and level: 3
# Subsequent level 3 string to LLM: multiples: Get equity valuation multiples for a given company.
#
# metrics: Get fundamental metrics for a given company.
#
# management_compensation: Get executive management team compensation for a given company over time.
#
# balance: Get the balance sheet for a given company.
#
# trailing_dividend_yield: Get the 1 year trailing dividend yield for a given company over time.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for an assessment of whether Tesla is overvalued or not. This falls under the category of equity valuation multiples.',
#     output='multiples'
# )
# Current Trail: ['equity-->fundamental-->multiples'] and level: 4
# [{'ids': ['id231'], 'embeddings': None, 'metadatas': [{'function_call': "{'name': 'obb-equity-fundamental-multiples_fmp', 'description': 'Get equity valuation multiples for a given company.', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp.', 'default': '', 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['fmp']}}, 'required': ['symbol', 'provider']}}", 'node_name': 'obb-equity-fundamental-multiples_fmp', 'provider_source': 'fmp', 'trail': 'equity-->fundamental-->multiples', 'type': 'provider_function'}], 'documents': ['empty'], 'uris': None, 'data': None}]
# code="from openbb import obb\ndf=obb.equity.fundamental.multiples(symbol='TSLA',provider='fmp')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=0 output='| symbol   |   revenue_per_share_ttm |   net_income_per_share_ttm |   operating_cash_flow_per_share_ttm |   free_cash_flow_per_share_ttm |   cash_per_share_ttm |   book_value_per_share_ttm |   tangible_book_value_per_share_ttm |   shareholders_equity_per_share_ttm |   interest_debt_per_share_ttm |   market_cap_ttm |   enterprise_value_ttm |   pe_ratio_ttm |   price_to_sales_ratio_ttm |   pocf_ratio_ttm |   pfcf_ratio_ttm |   pb_ratio_ttm |   ptb_ratio_ttm |   ev_to_sales_ttm |   enterprise_value_over_ebitda_ttm |   ev_to_operating_cash_flow_ttm |   ev_to_free_cash_flow_ttm |   earnings_yield_ttm |   free_cash_flow_yield_ttm |   debt_to_equity_ttm |   debt_to_assets_ttm |   net_debt_to_ebitda_ttm |   current_ratio_ttm |   interest_coverage_ttm |   income_quality_ttm |   dividend_yield_ttm |   dividend_yield_percentage_ttm |   dividend_to_market_cap_ttm |   dividend_per_share_ttm |   payout_ratio_ttm |   sales_general_and_administrative_to_revenue_ttm |   research_and_development_to_revenue_ttm |   intangibles_to_total_assets_ttm |   capex_to_operating_cash_flow_ttm |   capex_to_revenue_ttm |   capex_to_depreciation_ttm |   stock_based_compensation_to_revenue_ttm |   graham_number_ttm |   roic_ttm |   return_on_tangible_assets_ttm |   graham_net_net_ttm |   working_capital_ttm |   tangible_asset_value_ttm |   net_current_asset_value_ttm |   invested_capital_ttm |   average_receivables_ttm |   average_payables_ttm |   average_inventory_ttm |   days_sales_outstanding_ttm |   days_payables_outstanding_ttm |   days_of_inventory_on_hand_ttm |   receivables_turnover_ttm |   payables_turnover_ttm |   inventory_turnover_ttm |   roe_ttm |   capex_per_share_ttm |\n|:---------|------------------------:|---------------------------:|------------------------------------:|-------------------------------:|---------------------:|---------------------------:|------------------------------------:|------------------------------------:|------------------------------:|-----------------:|-----------------------:|---------------:|---------------------------:|-----------------:|-----------------:|---------------:|----------------:|------------------:|-----------------------------------:|--------------------------------:|---------------------------:|---------------------:|---------------------------:|---------------------:|---------------------:|-------------------------:|--------------------:|------------------------:|---------------------:|---------------------:|--------------------------------:|-----------------------------:|-------------------------:|-------------------:|--------------------------------------------------:|------------------------------------------:|----------------------------------:|-----------------------------------:|-----------------------:|----------------------------:|------------------------------------------:|--------------------:|-----------:|--------------------------------:|---------------------:|----------------------:|---------------------------:|------------------------------:|-----------------------:|--------------------------:|-----------------------:|------------------------:|-----------------------------:|--------------------------------:|--------------------------------:|---------------------------:|------------------------:|-------------------------:|----------:|----------------------:|\n| TSLA     |                 29.7379 |                    4.27338 |                              3.4479 |                       0.433773 |              8.54551 |                    20.2065 |                             20.2684 |                             20.2065 |                       1.91682 |      5.82284e+11 |            5.80027e+11 |        42.7249 |                     6.1458 |           52.954 |          421.334 |        9.03569 |         9.03569 |           6.12198 |                            43.4868 |                         52.8017 |                    419.701 |            0.0234055 |               ...
# | symbol   |   revenue_per_share_ttm |   net_income_per_share_ttm |   operating_cash_flow_per_share_ttm |   free_cash_flow_per_share_ttm |   cash_per_share_ttm |   book_value_per_share_ttm |   tangible_book_value_per_share_ttm |   shareholders_equity_per_share_ttm |   interest_debt_per_share_ttm |   market_cap_ttm |   enterprise_value_ttm |   pe_ratio_ttm |   price_to_sales_ratio_ttm |   pocf_ratio_ttm |   pfcf_ratio_ttm |   pb_ratio_ttm |   ptb_ratio_ttm |   ev_to_sales_ttm |   enterprise_value_over_ebitda_ttm |   ev_to_operating_cash_flow_ttm |   ev_to_free_cash_flow_ttm |   earnings_yield_ttm |   free_cash_flow_yield_ttm |   debt_to_equity_ttm |   debt_to_assets_ttm |   net_debt_to_ebitda_ttm |   current_ratio_ttm |   interest_coverage_ttm |   income_quality_ttm |   dividend_yield_ttm |   dividend_yield_percentage_ttm |   dividend_to_market_cap_ttm |   dividend_per_share_ttm |   payout_ratio_ttm |   sales_general_and_administrative_to_revenue_ttm |   research_and_development_to_revenue_ttm |   intangibles_to_total_assets_ttm |   capex_to_operating_cash_flow_ttm |   capex_to_revenue_ttm |   capex_to_depreciation_ttm |   stock_based_compensation_to_revenue_ttm |   graham_number_ttm |   roic_ttm |   return_on_tangible_assets_ttm |   graham_net_net_ttm |   working_capital_ttm |   tangible_asset_value_ttm |   net_current_asset_value_ttm |   invested_capital_ttm |   average_receivables_ttm |   average_payables_ttm |   average_inventory_ttm |   days_sales_outstanding_ttm |   days_payables_outstanding_ttm |   days_of_inventory_on_hand_ttm |   receivables_turnover_ttm |   payables_turnover_ttm |   inventory_turnover_ttm |   roe_ttm |   capex_per_share_ttm |
# |:---------|------------------------:|---------------------------:|------------------------------------:|-------------------------------:|---------------------:|---------------------------:|------------------------------------:|------------------------------------:|------------------------------:|-----------------:|-----------------------:|---------------:|---------------------------:|-----------------:|-----------------:|---------------:|----------------:|------------------:|-----------------------------------:|--------------------------------:|---------------------------:|---------------------:|---------------------------:|---------------------:|---------------------:|-------------------------:|--------------------:|------------------------:|---------------------:|---------------------:|--------------------------------:|-----------------------------:|-------------------------:|-------------------:|--------------------------------------------------:|------------------------------------------:|----------------------------------:|-----------------------------------:|-----------------------:|----------------------------:|------------------------------------------:|--------------------:|-----------:|--------------------------------:|---------------------:|----------------------:|---------------------------:|------------------------------:|-----------------------:|--------------------------:|-----------------------:|------------------------:|-----------------------------:|--------------------------------:|--------------------------------:|---------------------------:|------------------------:|-------------------------:|----------:|----------------------:|
# | TSLA     |                 29.7379 |                    4.27338 |                              3.4479 |                       0.433773 |              8.54551 |                    20.2065 |                             20.2684 |                             20.2065 |                       1.91682 |      5.82284e+11 |            5.80027e+11 |        42.7249 |                     6.1458 |           52.954 |          421.334 |        9.03569 |         9.03569 |           6.12198 |                            43.4868 |                         52.8017 |                    419.701 |            0.0234055 |                 0.00237341 |            0.0917083 |            0.0540531 |                -0.169216 |             1.71578 |                 36.4433 |             0.804467 |                    0 |                               0 |                    0.0101394 |                        0 |                  0 |                                                 0 |                                 0.0459022 |                        0.00553897 |                          -0.874192 |              -0.101356 |                    -1.97308 |                                 0.0202438 |             44.0781 |   0.163803 |                        0.125344 |             -1.84816 |            2.1082e+10 |                 6.4575e+10 |                     6.489e+09 |              0.0917083 |                 3.792e+09 |             1.4578e+10 |             1.48295e+10 |                      14.9745 |                         68.9939 |                         75.1225 |                    24.3748 |                 5.29032 |                  4.85873 |  0.235139 |              -3.01412 |

# %%
# Pass provider lists form OpenBB
PROVIDER_LIST = []

# %%
from typing import Optional
def function_calling_openbb(question:str)->Optional[str]:
    """This tool can be used to get financial data from the popular open-source platform OpenBB. 
       It takes a question and returns data by calling functions from OpenBB. OpenBB offers access to equity, options, crypto, forex, macro economy, fixed income, 
       and more while also offering a broad range of extensions to enhance the user experience according to their needs.

    Args:
        question (str): question to get information

    Returns:
        Optional[str]: It returns the data in markdown tables or None if no data is available
    """

    output = dspy_obb(question=question,provider_list=PROVIDER_LIST)
    return output

# %% [markdown]
# # AUTOGEN AGENT

# %%
from autogen import ConversableAgent
from autogen import register_function


llm_config = {"model":"gpt-4-turbo"}

system_message = "You have to respond to the question by building a plan first and then breakdown the plan into subquestions and use the function_calling_openbb tool to get financial data.\n" + \
                    "Make sure that you have plan well and ask relevant questions to the function_calling_openbb tool to get financial data. Also, restrict your question to one financial entity (like ticker) at one time.\n" + \
                    "For instance, if the user queries about the stock price quote of Apple and Microsoft, make sure to breakdown the it into subquestions stock price quote of Apple and stock price quote of Microsoft."


user_proxy = ConversableAgent(
    name = "Planner Admin",
    system_message=system_message,
    code_execution_config=False,
    llm_config=llm_config,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "TERMINATE" in msg["content"],
)

tool_proxy = ConversableAgent(
  name="Tool Proxy",
  llm_config={"model":"gpt-3.5-turbo"},
  system_message="Check if the Planner Admin is querying the OpenBB tool properly, and provide feedback if necessary. Answer TERMINATE after you are done.",
  is_termination_msg=lambda msg: "exit" in msg.get("content",""),
  default_auto_reply="Use the function_calling_openbb tool to answer the question",
  human_input_mode="NEVER",
  )

register_function(
    function_calling_openbb,
    caller=user_proxy,
    executor=tool_proxy,
    name = "function_calling_openbb",
    description="Tool to query OpenBB documentation to get financial data."
)

# %%
input_text = "What is the price consensus of Google and Microsoft? Compare and contrast between them"

chat_result = user_proxy.initiate_chat(
        recipient=tool_proxy,
        message=input_text,
        max_turns=5
    )
# Out:
# Planner Admin (to Tool Proxy):
#
# What is the price consensus of Google and Microsoft? Compare and contrast between them
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# Use the function_calling_openbb tool to answer the question
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# To effectively respond to your request about the price consensus of Google and Microsoft and their comparison, I will break down the task into two steps:
#
# 1. Retrieve the price consensus of Google.
# 2. Retrieve the price consensus of Microsoft.
#
# Let me gather this information for you now using the necessary function calls.
# ***** Suggested tool call (call_0iglvkukS55IcLAIXRDq8luV): function_calling_openbb *****
# Arguments:
# {"question": "price consensus of Google"}
# ****************************************************************************************
# ***** Suggested tool call (call_DOsGlWAKzFfUpKBv8XcskKBe): function_calling_openbb *****
# Arguments:
# {"question": "price consensus of Microsoft"}
# ****************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION function_calling_openbb...
# First level string: equity: Get historical and upcoming initial public offerings (IPOs). Get historical and upcoming dividend payments. Includes dividend amount, ex-dividend and payment dates. Get historical and upcoming stock split operations. Get historical and upcoming company earnings releases. Includes earnings per share (EPS) and revenue data. Get the closest peers for a given company.  Peers consist of companies trading on the same exchange, operating within the same sector and with comparable market capitalizations. Copmare reported company facts and fundamental data points. Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates. Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements. Get equity valuation multiples for a given company. Get the balance sheet for a given company. Get the growth of a company's balance sheet items over time. Get the cash flow statement for a given company. Get financial statements as reported by the company. Get the growth of a company's cash flow statement items over time. Get historical dividend data for a given company. Get historical earnings per share data for a given company. Get historical employee count data for a given company. Search Intrinio data tags to search in latest or historical attributes. Get the latest value of a data tag from Intrinio. Get the historical values of a data tag from Intrinio. Get the income statement for a given company. Get the growth of a company's income statement items over time. Get fundamental metrics for a given company. Get executive management team data for a given company. Get executive management team compensation for a given company over time. Get an extensive set of financial and accounting ratios for a given company over time. Get the revenue geographic breakdown for a given company over time. Get the revenue breakdown by business segment for a given company over time. Get historical stock splits for a given company. Get earnings call transcripts for a given company. Get the 1 year trailing dividend yield for a given company over time. Get data about major holders for a given company over time. Get data about institutional ownership for a given company over time.
#
# crypto: Get historical price data for cryptocurrency pair(s) within a provider. Search available cryptocurrency pairs within a provider.
#
# news: World News. Global news data. Company News. Get news for one or more companies.
#
# fixedincome: Treasury Constant Maturity.  Get data for 10-Year Treasury Constant Maturity Minus Selected Treasury Constant Maturity. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities.Select Treasury Constant Maturity.  Get data for Selected Treasury Constant Maturity Minus Federal Funds Rate Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Select Treasury Bill.  Get Selected Treasury Bill Minus Federal Funds Rate. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Get yield curve data by country and date. Government Treasury Rates. ICE BofA US Corporate Bond Indices.  The ICE BofA US Corporate Index tracks the performance of US dollar denominated investment grade corporate debt publicly issued in the US domestic market. Qualifying securities must have an investment grade rating (based on an average of Moody’s, S&P and Fitch), at least 18 months to final maturity at the time of issuance, at least one year remaining term to final maturity as of the rebalance date, a fixed coupon schedule and a minimum amount outstanding of $250 million. The ICE BofA US Corporate Index is a component of the US Corporate Master Index. Moody Corporate Bond Index.  Moody's Aaa and Baa are investment bonds that acts as an index of the performance of all bonds given an Aaa or Baa rating by Moody's Investors Service respectively. These corporate bonds often are used in macroeconomics as an alternative to the federal ten-year Treasury Bill as an indicator of the interest rate. High Quality Market Corporate Bond.  The HQM yield curve represents the high quality corporate bond market, i.e., corporate bonds rated AAA, AA, or A.  The HQM curve contains two regression terms. These terms are adjustment factors that blend AAA, AA, and A bonds into a single HQM yield curve that is the market-weighted average (MWA) quality of high quality bonds. Spot Rates.  The spot rates for any maturity is the yield on a bond that provides a single payment at that maturity. This is a zero coupon bond. Because each spot rate pertains to a single cashflow, it is the relevant interest rate concept for discounting a pension liability at the same maturity.
#
# currency: Currency Historical Price. Currency historical data.  Currency historical prices refer to the past exchange rates of one currency against another over a specific period. This data provides insight into the fluctuations and trends in the foreign exchange market, helping analysts, traders, and economists understand currency performance, evaluate economic health, and make predictions about future movements. Currency Search.  Search available currency pairs. Currency pairs are the national currencies from two countries coupled for trading on the foreign exchange (FX) marketplace. Both currencies will have exchange rates on which the trade will have its position basis. All trading within the forex market, whether selling, buying, or trading, will take place through currency pairs. (ref: Investopedia) Major currency pairs include pairs such as EUR/USD, USD/JPY, GBP/USD, etc. Snapshots of currency exchange rates from an indirect or direct perspective of a base currency.
#
#
# First level answer: equity
# Current Trail: ['equity'] and level: 2
# Subsequent level 2 string to LLM: estimates: Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates.
#
# market_snapshots: Get an updated equity market snapshot. This includes price data for thousands of stocks.
#
# compare: Get the closest peers for a given company.  Peers consist of companies trading on the same exchange, operating within the same sector and with comparable market capitalizations. Copmare reported company facts and fundamental data points.
#
# discovery: Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements.
#
# screener: Screen for companies meeting various criteria.  These criteria include market cap, price, beta, volume, and dividend yield.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for information related to the price consensus of Google. This falls under the "estimates" key, which includes analyst price targets, consensus price target, and forward estimates.',
#     output='estimates'
# )
# Current Trail: ['equity-->estimates'] and level: 3
# Subsequent level 3 string to LLM: consensus: Get consensus price target and recommendation.
#
# price_target: Get analyst price targets by company.
#
# historical: Get historical analyst estimates for earnings and revenue.
#
# forward_ebitda: Get forward EBITDA estimates.
#
# forward_eps: Get forward EPS estimates.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We see that the query is asking for the consensus price of Google. This falls under the "consensus" key.',
#     output='consensus'
# )
# Current Trail: ['equity-->estimates-->consensus'] and level: 4
# [{'ids': ['id213', 'id214', 'id215'], 'embeddings': None, 'metadatas': [{'function_call': "{'name': 'obb-equity-estimates-consensus_fmp', 'description': 'Get consensus price target and recommendation. Get it from provider fmp', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['fmp']}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_fmp', 'provider_source': 'fmp', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}, {'function_call': "{'name': 'obb-equity-estimates-consensus_intrinio', 'description': 'Get consensus price target and recommendation. Get it from provider intrinio', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['intrinio']}, 'industry_group_number': {'name': 'industry_group_number', 'type': 'integer', 'description': 'The Zacks industry group number.', 'default': None, 'optional': True, 'choices': None}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_intrinio', 'provider_source': 'intrinio', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}, {'function_call': "{'name': 'obb-equity-estimates-consensus_yfinance', 'description': 'Get consensus price target and recommendation. Get it from provider yfinance', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['yfinance']}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_yfinance', 'provider_source': 'yfinance', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}], 'documents': ['empty', 'empty', 'empty'], 'uris': None, 'data': None}]
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='GOOGL',provider='fmp')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> Unexpected error.\n'
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='GOOGL',provider='intrinio')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> Unexpected error.\n'
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='GOOGL',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=0 output='| symbol   |   target_high |   target_low |   target_consensus |   target_median | recommendation   |   recommendation_mean |   number_of_analysts |   current_price | currency   |\n|:---------|--------------:|-------------:|-------------------:|----------------:|:-----------------|----------------------:|---------------------:|----------------:|:-----------|\n| GOOGL    |           225 |          143 |             194.26 |             200 | buy              |                   1.9 |                   44 |          179.22 | USD        |\n'
#
# >>>>>>>> EXECUTING FUNCTION function_calling_openbb...
# First level string: equity: Get historical and upcoming initial public offerings (IPOs). Get historical and upcoming dividend payments. Includes dividend amount, ex-dividend and payment dates. Get historical and upcoming stock split operations. Get historical and upcoming company earnings releases. Includes earnings per share (EPS) and revenue data. Get the closest peers for a given company.  Peers consist of companies trading on the same exchange, operating within the same sector and with comparable market capitalizations. Copmare reported company facts and fundamental data points. Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates. Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements. Get equity valuation multiples for a given company. Get the balance sheet for a given company. Get the growth of a company's balance sheet items over time. Get the cash flow statement for a given company. Get financial statements as reported by the company. Get the growth of a company's cash flow statement items over time. Get historical dividend data for a given company. Get historical earnings per share data for a given company. Get historical employee count data for a given company. Search Intrinio data tags to search in latest or historical attributes. Get the latest value of a data tag from Intrinio. Get the historical values of a data tag from Intrinio. Get the income statement for a given company. Get the growth of a company's income statement items over time. Get fundamental metrics for a given company. Get executive management team data for a given company. Get executive management team compensation for a given company over time. Get an extensive set of financial and accounting ratios for a given company over time. Get the revenue geographic breakdown for a given company over time. Get the revenue breakdown by business segment for a given company over time. Get historical stock splits for a given company. Get earnings call transcripts for a given company. Get the 1 year trailing dividend yield for a given company over time. Get data about major holders for a given company over time. Get data about institutional ownership for a given company over time.
#
# fixedincome: Treasury Constant Maturity.  Get data for 10-Year Treasury Constant Maturity Minus Selected Treasury Constant Maturity. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities.Select Treasury Constant Maturity.  Get data for Selected Treasury Constant Maturity Minus Federal Funds Rate Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Select Treasury Bill.  Get Selected Treasury Bill Minus Federal Funds Rate. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Get yield curve data by country and date. Government Treasury Rates. ICE BofA US Corporate Bond Indices.  The ICE BofA US Corporate Index tracks the performance of US dollar denominated investment grade corporate debt publicly issued in the US domestic market. Qualifying securities must have an investment grade rating (based on an average of Moody’s, S&P and Fitch), at least 18 months to final maturity at the time of issuance, at least one year remaining term to final maturity as of the rebalance date, a fixed coupon schedule and a minimum amount outstanding of $250 million. The ICE BofA US Corporate Index is a component of the US Corporate Master Index. Moody Corporate Bond Index.  Moody's Aaa and Baa are investment bonds that acts as an index of the performance of all bonds given an Aaa or Baa rating by Moody's Investors Service respectively. These corporate bonds often are used in macroeconomics as an alternative to the federal ten-year Treasury Bill as an indicator of the interest rate. High Quality Market Corporate Bond.  The HQM yield curve represents the high quality corporate bond market, i.e., corporate bonds rated AAA, AA, or A.  The HQM curve contains two regression terms. These terms are adjustment factors that blend AAA, AA, and A bonds into a single HQM yield curve that is the market-weighted average (MWA) quality of high quality bonds. Spot Rates.  The spot rates for any maturity is the yield on a bond that provides a single payment at that maturity. This is a zero coupon bond. Because each spot rate pertains to a single cashflow, it is the relevant interest rate concept for discounting a pension liability at the same maturity.
#
# crypto: Get historical price data for cryptocurrency pair(s) within a provider. Search available cryptocurrency pairs within a provider.
#
# news: World News. Global news data. Company News. Get news for one or more companies.
#
# derivatives: Get the complete options chain for a ticker. Historical futures prices. Futures Term Structure, current or historical.
#
#
# First level answer: equity
# Current Trail: ['equity'] and level: 2
# Subsequent level 2 string to LLM: estimates: Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates.
#
# market_snapshots: Get an updated equity market snapshot. This includes price data for thousands of stocks.
#
# discovery: Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements.
#
# compare: Get the closest peers for a given company.  Peers consist of companies trading on the same exchange, operating within the same sector and with comparable market capitalizations. Copmare reported company facts and fundamental data points.
#
# screener: Screen for companies meeting various criteria.  These criteria include market cap, price, beta, volume, and dividend yield.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for information related to analyst price targets, consensus price target, and recommendation for Microsoft. This falls under the "estimates" key.',
#     output='estimates'
# )
# Current Trail: ['equity-->estimates'] and level: 3
# Subsequent level 3 string to LLM: consensus: Get consensus price target and recommendation.
#
# price_target: Get analyst price targets by company.
#
# forward_eps: Get forward EPS estimates.
#
# historical: Get historical analyst estimates for earnings and revenue.
#
# forward_ebitda: Get forward EBITDA estimates.
#
#
# LLM Answer: Prediction(
#     rationale="produce the output. We are looking for the consensus price target of Microsoft, which falls under the 'consensus' key.",
#     output='consensus'
# )
# Current Trail: ['equity-->estimates-->consensus'] and level: 4
# [{'ids': ['id213', 'id214', 'id215'], 'embeddings': None, 'metadatas': [{'function_call': "{'name': 'obb-equity-estimates-consensus_fmp', 'description': 'Get consensus price target and recommendation. Get it from provider fmp', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['fmp']}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_fmp', 'provider_source': 'fmp', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}, {'function_call': "{'name': 'obb-equity-estimates-consensus_intrinio', 'description': 'Get consensus price target and recommendation. Get it from provider intrinio', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['intrinio']}, 'industry_group_number': {'name': 'industry_group_number', 'type': 'integer', 'description': 'The Zacks industry group number.', 'default': None, 'optional': True, 'choices': None}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_intrinio', 'provider_source': 'intrinio', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}, {'function_call': "{'name': 'obb-equity-estimates-consensus_yfinance', 'description': 'Get consensus price target and recommendation. Get it from provider yfinance', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['yfinance']}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_yfinance', 'provider_source': 'yfinance', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}], 'documents': ['empty', 'empty', 'empty'], 'uris': None, 'data': None}]
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='MSFT',provider='fmp')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> Unexpected error.\n'
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='MSFT',provider='intrinio')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> Unexpected error.\n'
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='MSFT',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=0 output='| symbol   |   target_high |   target_low |   target_consensus |   target_median | recommendation   |   recommendation_mean |   number_of_analysts |   current_price | currency   |\n|:---------|--------------:|-------------:|-------------------:|----------------:|:-----------------|----------------------:|---------------------:|----------------:|:-----------|\n| MSFT     |        560.46 |       407.27 |             455.76 |          448.37 | buy              |                   1.6 |                   46 |          447.67 | USD        |\n'
# Tool Proxy (to Planner Admin):
#
# Tool Proxy (to Planner Admin):
#
# ***** Response from calling tool (call_0iglvkukS55IcLAIXRDq8luV) *****
# | symbol   |   target_high |   target_low |   target_consensus |   target_median | recommendation   |   recommendation_mean |   number_of_analysts |   current_price | currency   |
# |:---------|--------------:|-------------:|-------------------:|----------------:|:-----------------|----------------------:|---------------------:|----------------:|:-----------|
# | GOOGL    |           225 |          143 |             194.26 |             200 | buy              |                   1.9 |                   44 |          179.22 | USD        |
#
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# ***** Response from calling tool (call_DOsGlWAKzFfUpKBv8XcskKBe) *****
# | symbol   |   target_high |   target_low |   target_consensus |   target_median | recommendation   |   recommendation_mean |   number_of_analysts |   current_price | currency   |
# |:---------|--------------:|-------------:|-------------------:|----------------:|:-----------------|----------------------:|---------------------:|----------------:|:-----------|
# | MSFT     |        560.46 |       407.27 |             455.76 |          448.37 | buy              |                   1.6 |                   46 |          447.67 | USD        |
#
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# Here is the price consensus information for Google (Alphabet Inc.) and Microsoft:
#
# **Google (Alphabet Inc., GOOGL):**
# - Target High Price: $225.00
# - Target Low Price: $143.00
# - Target Consensus Price: $194.26
# - Target Median Price: $200.00
# - Recommendation: Buy
# - Recommendation Mean Score: 1.9
# - Number of Analysts: 44
# - Current Price: $179.22
# - Currency: USD
#
# **Microsoft (MSFT):**
# - Target High Price: $560.46
# - Target Low Price: $407.27
# - Target Consensus Price: $455.76
# - Target Median Price: $448.37
# - Recommendation: Buy
# - Recommendation Mean Score: 1.6
# - Number of Analysts: 46
# - Current Price: $447.67
# - Currency: USD
#
# ### Comparison and Contrast:
# - **Target Price Range:**
#   - Google has a lower high price target and a significantly lower low price target compared to Microsoft, indicating less volatility and a narrower price target range.
# - **Consensus and Median Prices:**
#   - Microsoft's consensus and median target prices are substantially higher than Google's, reflecting more bullish sentiment from analysts.
# - **Recommendation and Analytical Consensus:**
#   - Both companies have a "buy" recommendation. However, Google's recommendation mean score is slightly higher than Microsoft's, indicating a slightly stronger buy consensus among the analysts.
# - **Number of Analysts:**
#   - Both stocks are intensely followed by the investment community, with Microsoft slightly leading in the number of analysts reviewing the stock.
# - **Current Prices:**
#   - Microsoft's current price is much higher than Google's, aligning with the analysts' higher target prices for Microsoft.
#
# This information manifests differing market sentiments and expectations around each company's future performance within their respective sectors and overall market conditions.
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# Use the function_calling_openbb tool to answer the question
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# Since we have already executed the function_calling_openbb tool to gather the price consensus of Google and Microsoft and provided their detailed comparison, please let me know if there is anything else you need or any other aspects you would like to explore further!
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# Use the function_calling_openbb tool to answer the question
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# It appears there might have been some confusion regarding the request to use the function_calling_openbb tool as it was already used to fetch and provide the price consensus for Google and Microsoft. Let's clarify what has been completed:
#
# 1. **Price Consensus for Google (GOOGL) and Microsoft (MSFT)**:
#    - Using the tool, we gathered and presented detailed information about the target high, target low, consensus prices, recommendations, and other analyst metrics for both companies.
#
# 2. **Result Summary**:
#    - **Google**: The price consensus shows a median target price of $200, with a "buy" recommendation, based on the opinions of 44 analysts.
#    - **Microsoft**: The price consensus shows a median target nasdaq price of $448.37, also with a "buy" recommendation, but from a slightly larger group of 46 analysts.
#
# This broad comparison captures how analysts currently view the potential market performance of these two tech giants.
#
# If you need additional specific data or analysis regarding Google, Microsoft, or any other financial information, please let me know the exact details, and I will proceed to gather that using the appropriate tools!
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# Use the function_calling_openbb tool to answer the question
#
# --------------------------------------------------------------------------------

# %%
input_text = "What is the price consensus of Google and Microsoft? Compare and contrast between them"

chat_result = user_proxy.initiate_chat(
        recipient=tool_proxy,
        message=input_text,
        max_turns=5
    )
# Out:
# Planner Admin (to Tool Proxy):
# What is the price consensus of Google and Microsoft? Compare and contrast between them
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# I'm sorry, but I am unable to provide real-time or up-to-date financial data including the current price consensus of Google and Microsoft. Would you like me to help you with any other information or analysis regarding these companies or any other topic?
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# To provide a comparison of the price consensus for Google and Microsoft, we will proceed as follows:
#
# 1. **Retrieve Google's (Alphabet Inc.) Price Consensus**: By querying the latest financial data available regardring Google's stock price consensus.
# 2. **Retrieve Microsoft's Price Consensus**: By querying the latest financial data available regarding Microsoft's stock price consensus.
# 3. **Compare the Data**: After retrieving the information, we will compare the consensus estimates for both companies, highlighting any significant differences or insights.
#
# Let's start by retrieving the data for both companies:
#
# **Subquestion 1:** What is the current price consensus for Google (Alphabet Inc.)?
# **Subquestion 2:** What is the current price consensus for Microsoft?
# ***** Suggested tool call (call_TOlzKylwz3SRy37zZucOXNqQ): function_calling_openbb *****
# Arguments:
# {"question": "What is the current price consensus for Google (Alphabet Inc.)?"}
# ****************************************************************************************
# ***** Suggested tool call (call_aZ8BRAYLf5jUWIgS2CClUC2Q): function_calling_openbb *****
# Arguments:
# {"question": "What is the current price consensus for Microsoft?"}
# ****************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION function_calling_openbb...
# First level string: equity: Get historical and upcoming initial public offerings (IPOs). Get historical and upcoming dividend payments. Includes dividend amount, ex-dividend and payment dates. Get historical and upcoming stock split operations. Get historical and upcoming company earnings releases. Includes earnings per share (EPS) and revenue data. Get the closest peers for a given company.  Peers consist of companies trading on the same exchange, operating within the same sector and with comparable market capitalizations. Copmare reported company facts and fundamental data points. Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates. Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements. Get equity valuation multiples for a given company. Get the balance sheet for a given company. Get the growth of a company's balance sheet items over time. Get the cash flow statement for a given company. Get financial statements as reported by the company. Get the growth of a company's cash flow statement items over time. Get historical dividend data for a given company. Get historical earnings per share data for a given company. Get historical employee count data for a given company. Search Intrinio data tags to search in latest or historical attributes. Get the latest value of a data tag from Intrinio. Get the historical values of a data tag from Intrinio. Get the income statement for a given company. Get the growth of a company's income statement items over time. Get fundamental metrics for a given company. Get executive management team data for a given company. Get executive management team compensation for a given company over time. Get an extensive set of financial and accounting ratios for a given company over time. Get the revenue geographic breakdown for a given company over time. Get the revenue breakdown by business segment for a given company over time. Get historical stock splits for a given company. Get earnings call transcripts for a given company. Get the 1 year trailing dividend yield for a given company over time. Get data about major holders for a given company over time. Get data about institutional ownership for a given company over time.
#
# crypto: Get historical price data for cryptocurrency pair(s) within a provider. Search available cryptocurrency pairs within a provider.
#
# news: World News. Global news data. Company News. Get news for one or more companies.
#
# economy: Get Forecasted GDP Data. Get Nominal GDP Data. Get Real GDP Data. Get the upcoming, or historical, economic calendar of global events. Get Consumer Price Index (CPI).  Returns either the rescaled index value, or a rate of change (inflation). Get Market Risk Premium by country. Balance of Payments Reports. Search for FRED series or economic releases by ID or string.  This does not return the observation values, only the metadata. Use this function to find series IDs for `fred_series()`. Get data by series ID from FRED. Get Money Measures (M1/M2 and components).  The Federal Reserve publishes as part of the H.6 Release. Get global unemployment data. Use the composite leading indicator (CLI).  It is designed to provide early signals of turning points in business cycles showing fluctuation of the economic activity around its long term potential level.  CLIs show short-term economic movements in qualitative rather than quantitative terms. Get Short-term interest rates.  They are the rates at which short-term borrowings are effected between financial institutions or the rate at which short-term government paper is issued or traded in the market.  Short-term interest rates are generally averages of daily rates, measured as a percentage. Short-term interest rates are based on three-month money market rates where available. Typical standardised names are "money market rate" and "treasury bill rate". Get Long-term interest rates that refer to government bonds maturing in ten years.  Rates are mainly determined by the price charged by the lender, the risk from the borrower and the fall in the capital value. Long-term interest rates are generally averages of daily rates, measured as a percentage. These interest rates are implied by the prices at which the government bonds are traded on financial markets, not the interest rates at which the loans were issued. In all cases, they refer to bonds whose capital repayment is guaranteed by governments. Long-term interest rates are one of the determinants of business investment. Low long-term interest rates encourage investment in new equipment and high interest rates discourage it. Investment is, in turn, a major source of economic growth. Query the Geo Fred API for regional economic data by series group.  The series group ID is found by using `fred_search` and the `series_id` parameter. Get a profile of country statistics and economic indicators. Get the available economic indicators for a provider. Get economic indicators by country and indicator. Get the balance sheet holdings of a central bank. Get the Share Price Index by country from the OECD Short-Term Economics Statistics. Get the House Price Index by country from the OECD Short-Term Economics Statistics. Get immediate interest rates by country. Get retail prices for common items.
#
# derivatives: Get the complete options chain for a ticker. Historical futures prices. Futures Term Structure, current or historical.
#
#
# First level answer: equity
# Current Trail: ['equity'] and level: 2
# Subsequent level 2 string to LLM: estimates: Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates.
#
# market_snapshots: Get an updated equity market snapshot. This includes price data for thousands of stocks.
#
# profile: Get general information about a company. This includes company name, industry, sector and price data.
#
# discovery: Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements.
#
# fundamental: Get equity valuation multiples for a given company. Get the balance sheet for a given company. Get the growth of a company's balance sheet items over time. Get the cash flow statement for a given company. Get financial statements as reported by the company. Get the growth of a company's cash flow statement items over time. Get historical dividend data for a given company. Get historical earnings per share data for a given company. Get historical employee count data for a given company. Search Intrinio data tags to search in latest or historical attributes. Get the latest value of a data tag from Intrinio. Get the historical values of a data tag from Intrinio. Get the income statement for a given company. Get the growth of a company's income statement items over time. Get fundamental metrics for a given company. Get executive management team data for a given company. Get executive management team compensation for a given company over time. Get an extensive set of financial and accounting ratios for a given company over time. Get the revenue geographic breakdown for a given company over time. Get the revenue breakdown by business segment for a given company over time. Get historical stock splits for a given company. Get earnings call transcripts for a given company. Get the 1 year trailing dividend yield for a given company over time.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for the current price consensus for Google (Alphabet Inc.), which falls under the estimates key.',
#     output='estimates'
# )
# Current Trail: ['equity-->estimates'] and level: 3
# Subsequent level 3 string to LLM: consensus: Get consensus price target and recommendation.
#
# price_target: Get analyst price targets by company.
#
# historical: Get historical analyst estimates for earnings and revenue.
#
# forward_eps: Get forward EPS estimates.
#
# forward_ebitda: Get forward EBITDA estimates.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for the current price consensus for Google (Alphabet Inc.), which falls under the consensus key.',
#     output='consensus'
# )
# Current Trail: ['equity-->estimates-->consensus'] and level: 4
# [{'ids': ['id213', 'id214', 'id215'], 'embeddings': None, 'metadatas': [{'function_call': "{'name': 'obb-equity-estimates-consensus_fmp', 'description': 'Get consensus price target and recommendation. Get it from provider fmp', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['fmp']}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_fmp', 'provider_source': 'fmp', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}, {'function_call': "{'name': 'obb-equity-estimates-consensus_intrinio', 'description': 'Get consensus price target and recommendation. Get it from provider intrinio', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['intrinio']}, 'industry_group_number': {'name': 'industry_group_number', 'type': 'integer', 'description': 'The Zacks industry group number.', 'default': None, 'optional': True, 'choices': None}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_intrinio', 'provider_source': 'intrinio', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}, {'function_call': "{'name': 'obb-equity-estimates-consensus_yfinance', 'description': 'Get consensus price target and recommendation. Get it from provider yfinance', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['yfinance']}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_yfinance', 'provider_source': 'yfinance', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}], 'documents': ['empty', 'empty', 'empty'], 'uris': None, 'data': None}]
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='GOOGL',provider='fmp')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> Unexpected error.\n'
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='GOOGL',provider='intrinio')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> Unexpected error.\n'
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='GOOGL',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=0 output='| symbol   |   target_high |   target_low |   target_consensus |   target_median | recommendation   |   recommendation_mean |   number_of_analysts |   current_price | currency   |\n|:---------|--------------:|-------------:|-------------------:|----------------:|:-----------------|----------------------:|---------------------:|----------------:|:-----------|\n| GOOGL    |           225 |          143 |             194.26 |             200 | buy              |                   1.9 |                   44 |          179.22 | USD        |\n'
#
# >>>>>>>> EXECUTING FUNCTION function_calling_openbb...
# First level string: equity: Get historical and upcoming initial public offerings (IPOs). Get historical and upcoming dividend payments. Includes dividend amount, ex-dividend and payment dates. Get historical and upcoming stock split operations. Get historical and upcoming company earnings releases. Includes earnings per share (EPS) and revenue data. Get the closest peers for a given company.  Peers consist of companies trading on the same exchange, operating within the same sector and with comparable market capitalizations. Copmare reported company facts and fundamental data points. Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates. Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements. Get equity valuation multiples for a given company. Get the balance sheet for a given company. Get the growth of a company's balance sheet items over time. Get the cash flow statement for a given company. Get financial statements as reported by the company. Get the growth of a company's cash flow statement items over time. Get historical dividend data for a given company. Get historical earnings per share data for a given company. Get historical employee count data for a given company. Search Intrinio data tags to search in latest or historical attributes. Get the latest value of a data tag from Intrinio. Get the historical values of a data tag from Intrinio. Get the income statement for a given company. Get the growth of a company's income statement items over time. Get fundamental metrics for a given company. Get executive management team data for a given company. Get executive management team compensation for a given company over time. Get an extensive set of financial and accounting ratios for a given company over time. Get the revenue geographic breakdown for a given company over time. Get the revenue breakdown by business segment for a given company over time. Get historical stock splits for a given company. Get earnings call transcripts for a given company. Get the 1 year trailing dividend yield for a given company over time. Get data about major holders for a given company over time. Get data about institutional ownership for a given company over time.
#
# crypto: Get historical price data for cryptocurrency pair(s) within a provider. Search available cryptocurrency pairs within a provider.
#
# fixedincome: Treasury Constant Maturity.  Get data for 10-Year Treasury Constant Maturity Minus Selected Treasury Constant Maturity. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities.Select Treasury Constant Maturity.  Get data for Selected Treasury Constant Maturity Minus Federal Funds Rate Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Select Treasury Bill.  Get Selected Treasury Bill Minus Federal Funds Rate. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Get yield curve data by country and date. Government Treasury Rates. ICE BofA US Corporate Bond Indices.  The ICE BofA US Corporate Index tracks the performance of US dollar denominated investment grade corporate debt publicly issued in the US domestic market. Qualifying securities must have an investment grade rating (based on an average of Moody’s, S&P and Fitch), at least 18 months to final maturity at the time of issuance, at least one year remaining term to final maturity as of the rebalance date, a fixed coupon schedule and a minimum amount outstanding of $250 million. The ICE BofA US Corporate Index is a component of the US Corporate Master Index. Moody Corporate Bond Index.  Moody's Aaa and Baa are investment bonds that acts as an index of the performance of all bonds given an Aaa or Baa rating by Moody's Investors Service respectively. These corporate bonds often are used in macroeconomics as an alternative to the federal ten-year Treasury Bill as an indicator of the interest rate. High Quality Market Corporate Bond.  The HQM yield curve represents the high quality corporate bond market, i.e., corporate bonds rated AAA, AA, or A.  The HQM curve contains two regression terms. These terms are adjustment factors that blend AAA, AA, and A bonds into a single HQM yield curve that is the market-weighted average (MWA) quality of high quality bonds. Spot Rates.  The spot rates for any maturity is the yield on a bond that provides a single payment at that maturity. This is a zero coupon bond. Because each spot rate pertains to a single cashflow, it is the relevant interest rate concept for discounting a pension liability at the same maturity.
#
# derivatives: Get the complete options chain for a ticker. Historical futures prices. Futures Term Structure, current or historical.
#
# fixedincome: Ameribor.  Ameribor (short for the American interbank offered rate) is a benchmark interest rate that reflects the true cost of short-term interbank borrowing. This rate is based on transactions in overnight unsecured loans conducted on the American Financial Exchange (AFX). Sterling Overnight Index Average.  SONIA (Sterling Overnight Index Average) is an important interest rate benchmark. SONIA is based on actual transactions and reflects the average of the interest rates that banks pay to borrow sterling overnight from other financial institutions and other institutional investors. Interest on Reserve Balances.  Get Interest Rate on Reserve Balances data A bank rate is the interest rate a nation's central bank charges to its domestic banks to borrow money. The rates central banks charge are set to stabilize the economy. In the United States, the Federal Reserve System's Board of Governors set the bank rate, also known as the discount rate. Fed Funds Rate.  Get Effective Federal Funds Rate data. A bank rate is the interest rate a nation's central bank charges to its domestic banks to borrow money. The rates central banks charge are set to stabilize the economy. In the United States, the Federal Reserve System's Board of Governors set the bank rate, also known as the discount rate. Fed Funds Rate Projections.  The projections for the federal funds rate are the value of the midpoint of the projected appropriate target range for the federal funds rate or the projected appropriate target level for the federal funds rate at the end of the specified calendar year or over the longer run. Euro Short-Term Rate.  The euro short-term rate (€STR) reflects the wholesale euro unsecured overnight borrowing costs of banks located in the euro area. The €STR is published on each TARGET2 business day based on transactions conducted and settled on the previous TARGET2 business day (the reporting date “T”) with a maturity date of T+1 which are deemed to have been executed at arm’s length and thus reflect market rates in an unbiased way. European Central Bank Interest Rates.  The Governing Council of the ECB sets the key interest rates for the euro area:  - The interest rate on the main refinancing operations (MRO), which provide the bulk of liquidity to the banking system. - The rate on the deposit facility, which banks may use to make overnight deposits with the Eurosystem. - The rate on the marginal lending facility, which offers overnight credit to banks from the Eurosystem. Discount Window Primary Credit Rate.  A bank rate is the interest rate a nation's central bank charges to its domestic banks to borrow money. The rates central banks charge are set to stabilize the economy. In the United States, the Federal Reserve System's Board of Governors set the bank rate, also known as the discount rate.
#
#
# First level answer: equity
# Current Trail: ['equity'] and level: 2
# Subsequent level 2 string to LLM: estimates: Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates.
#
# market_snapshots: Get an updated equity market snapshot. This includes price data for thousands of stocks.
#
# discovery: Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements.
#
# price: Get the latest quote for a given stock. Quote includes price, volume, and other data. Get the National Best Bid and Offer for a given stock. Get price performance data for a given stock. This includes price changes for different time periods.
#
# profile: Get general information about a company. This includes company name, industry, sector and price data.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for the current price consensus for Microsoft, which involves analyst price targets and consensus price target. This falls under the "estimates" key.',
#     output='estimates'
# )
# Current Trail: ['equity-->estimates'] and level: 3
# Subsequent level 3 string to LLM: consensus: Get consensus price target and recommendation.
#
# price_target: Get analyst price targets by company.
#
# forward_eps: Get forward EPS estimates.
#
# historical: Get historical analyst estimates for earnings and revenue.
#
# forward_ebitda: Get forward EBITDA estimates.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for the current price consensus for Microsoft, which is related to the consensus key.',
#     output='consensus'
# )
# Current Trail: ['equity-->estimates-->consensus'] and level: 4
# [{'ids': ['id213', 'id214', 'id215'], 'embeddings': None, 'metadatas': [{'function_call': "{'name': 'obb-equity-estimates-consensus_fmp', 'description': 'Get consensus price target and recommendation. Get it from provider fmp', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['fmp']}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_fmp', 'provider_source': 'fmp', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}, {'function_call': "{'name': 'obb-equity-estimates-consensus_intrinio', 'description': 'Get consensus price target and recommendation. Get it from provider intrinio', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['intrinio']}, 'industry_group_number': {'name': 'industry_group_number', 'type': 'integer', 'description': 'The Zacks industry group number.', 'default': None, 'optional': True, 'choices': None}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_intrinio', 'provider_source': 'intrinio', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}, {'function_call': "{'name': 'obb-equity-estimates-consensus_yfinance', 'description': 'Get consensus price target and recommendation. Get it from provider yfinance', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Multiple items allowed for provider(s): fmp, intrinio, yfinance.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['yfinance']}}, 'required': ['provider']}}", 'node_name': 'obb-equity-estimates-consensus_yfinance', 'provider_source': 'yfinance', 'trail': 'equity-->estimates-->consensus', 'type': 'provider_function'}], 'documents': ['empty', 'empty', 'empty'], 'uris': None, 'data': None}]
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='MSFT',provider='fmp')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> Unexpected error.\n'
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='MSFT',provider='intrinio')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> Unexpected error.\n'
# code="from openbb import obb\ndf=obb.equity.estimates.consensus(symbol='MSFT',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=0 output='| symbol   |   target_high |   target_low |   target_consensus |   target_median | recommendation   |   recommendation_mean |   number_of_analysts |   current_price | currency   |\n|:---------|--------------:|-------------:|-------------------:|----------------:|:-----------------|----------------------:|---------------------:|----------------:|:-----------|\n| MSFT     |        560.46 |       407.27 |             455.76 |          448.37 | buy              |                   1.6 |                   46 |          447.67 | USD        |\n'
# Tool Proxy (to Planner Admin):
#
# Tool Proxy (to Planner Admin):
#
# ***** Response from calling tool (call_TOlzKylwz3SRy37zZucOXNqQ) *****
# | symbol   |   target_high |   target_low |   target_consensus |   target_median | recommendation   |   recommendation_mean |   number_of_analysts |   current_price | currency   |
# |:---------|--------------:|-------------:|-------------------:|----------------:|:-----------------|----------------------:|---------------------:|----------------:|:-----------|
# | GOOGL    |           225 |          143 |             194.26 |             200 | buy              |                   1.9 |                   44 |          179.22 | USD        |
#
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# ***** Response from calling tool (call_aZ8BRAYLf5jUWIgS2CClUC2Q) *****
# | symbol   |   target_high |   target_low |   target_consensus |   target_median | recommendation   |   recommendation_mean |   number_of_analysts |   current_price | currency   |
# |:---------|--------------:|-------------:|-------------------:|----------------:|:-----------------|----------------------:|---------------------:|----------------:|:-----------|
# | MSFT     |        560.46 |       407.27 |             455.76 |          448.37 | buy              |                   1.6 |                   46 |          447.67 | USD        |
#
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# Here's the comparison of the price consensus for Google (Alphabet Inc.) and Microsoft:
#
# ### Google (Alphabet Inc.) - GOOGL
# - **Target High:** $225
# - **Target Low:** $143
# - **Target Consensus:** $194.26
# - **Target Median:** $200
# - **Recommendation:** Buy (Average score: 1.9)
# - **Number of Analysts:** 44
# - **Current Price:** $179.22
#
# ### Microsoft - MSFT
# - **Target High:** $560.46
# - **Target Low:** $407.27
# - **Target Consensus:** $455.76
# - **Target Median:** $448.37
# - **Recommendational:** Buy (Average score: 1.6)
# - **Number of Analysts:** 46
# - **Current Price:** $447.67
#
# ### Comparison:
# - **Price Target Range:**
#   - Google has a narrower price target range ($143 to $225) compared to Microsoft's wider range ($407.27 to $560.46).
# - **Consensus and Median Targets:**
#   - Google's consensus and median price targets are lower relative to its current price than Microsoft's, indicating more conservative growth expectations.
# - **Recommendation:**
#   - Both companies are considered a buy by analysts, although Google has a slightly higher recommendation mean.
# - **Analyst Sentiment:**
#   - Despite Google having fewer analysts (44 vs. 46), their recommendation intensity (1.9 vs. 1.6) is somewhat stronger.
#
# This comparative overview gives an insight into how the market views the future pricing potential and overall recommendations for these two tech giants.
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# The comparison of the price consensus for Google and Microsoft has been successfully provided. If you require further analysis or have any additional questions, feel free to ask. How may I assist you further?
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# The comparison of the price consensus for Google and Microsoft has been successfully provided. If you require further analysis or have any additional questions, feel free to ask. How may I assist you further?
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# Thank you! If you have any more questions or need assistance with any other topics or analyses, please feel free to let me know. I'm here to help. Just ask away!
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# Thank for your appreciation! If you have any more questions or need assistance with any other topics or analyses, please feel free to let me know. I'm here to help. Just ask away!
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# Great and thank you for your willingness to help further! If you have any more questions in the future or need any assistance, don't hesitate to reach out. Have a wonderful day! Feel free to TERMINATE the session whenever you're ready.
#
# --------------------------------------------------------------------------------

# %%
input_text = "How is the Gold futures market doing? Compare and contrast between Gold and Bitcoin?"

chat_result = user_proxy.initiate_chat(
        recipient=tool_proxy,
        message=input_text,
        max_turns=5
    )
# Out:
# Planner Admin (to Tool Proxy):
#
# How is the Gold futures market doing? Compare and contrast between Gold and Bitcoin?
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# I'm sorry, but the request for information on the Gold futures market and a comparison between Gold and Bitcoin does not pertain to the OpenBB tool or its primary functionalities. The OpenBB tool is used to provide data and insights related to event planning, such as budget management, vendor coordination, and scheduling.
#
# If you have any specific event planning queries or require assistance with utilizing the OpenBB tool, please let me know so I can assist you further.
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# To respond to your query regarding the Gold futures market as well as the comparative analysis between Gold and Bitcoin, we can leverage the OpenBB tool to gather relevant financial data. Here's the approach we'll take:
#
# ### Plan
# 1. **Fetch Gold Futures Data**: We'll collect the latest price and trend data for Gold futures.
# 2. **Fetch Bitcoin Price Data**: Similarly, we'll collect the latest price and trend data for Bitcoin.
# 3. **Comparison**: We'll then compare the two assets based on their recent performance metrics and trends.
#
# ### Subquestions to be executed:
# 1. What is the latest price of Gold futures?
# 2. What is the latest price of Bitcoin?
#
# Let's proceed by gathering the data for these subquestions using the OpenBB tool.
# ***** Suggested tool call (call_9JAyQgCP7jEomDQzNwVxtxq0): function_calling_openbb *****
# Arguments:
# {"question": "latest price of Gold futures"}
# ****************************************************************************************
# ***** Suggested tool call (call_vkjCZiqWuwLiHZ0UBeufvVtQ): function_calling_openbb *****
# Arguments:
# {"question": "latest price of Bitcoin"}
# ****************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION function_calling_openbb...
# First level string: derivatives: Get the complete options chain for a ticker. Historical futures prices. Futures Term Structure, current or historical.
#
# currency: Currency Historical Price. Currency historical data.  Currency historical prices refer to the past exchange rates of one currency against another over a specific period. This data provides insight into the fluctuations and trends in the foreign exchange market, helping analysts, traders, and economists understand currency performance, evaluate economic health, and make predictions about future movements. Currency Search.  Search available currency pairs. Currency pairs are the national currencies from two countries coupled for trading on the foreign exchange (FX) marketplace. Both currencies will have exchange rates on which the trade will have its position basis. All trading within the forex market, whether selling, buying, or trading, will take place through currency pairs. (ref: Investopedia) Major currency pairs include pairs such as EUR/USD, USD/JPY, GBP/USD, etc. Snapshots of currency exchange rates from an indirect or direct perspective of a base currency.
#
# fixedincome: Treasury Constant Maturity.  Get data for 10-Year Treasury Constant Maturity Minus Selected Treasury Constant Maturity. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities.Select Treasury Constant Maturity.  Get data for Selected Treasury Constant Maturity Minus Federal Funds Rate Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Select Treasury Bill.  Get Selected Treasury Bill Minus Federal Funds Rate. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Get yield curve data by country and date. Government Treasury Rates. ICE BofA US Corporate Bond Indices.  The ICE BofA US Corporate Index tracks the performance of US dollar denominated investment grade corporate debt publicly issued in the US domestic market. Qualifying securities must have an investment grade rating (based on an average of Moody’s, S&P and Fitch), at least 18 months to final maturity at the time of issuance, at least one year remaining term to final maturity as of the rebalance date, a fixed coupon schedule and a minimum amount outstanding of $250 million. The ICE BofA US Corporate Index is a component of the US Corporate Master Index. Moody Corporate Bond Index.  Moody's Aaa and Baa are investment bonds that acts as an index of the performance of all bonds given an Aaa or Baa rating by Moody's Investors Service respectively. These corporate bonds often are used in macroeconomics as an alternative to the federal ten-year Treasury Bill as an indicator of the interest rate. High Quality Market Corporate Bond.  The HQM yield curve represents the high quality corporate bond market, i.e., corporate bonds rated AAA, AA, or A.  The HQM curve contains two regression terms. These terms are adjustment factors that blend AAA, AA, and A bonds into a single HQM yield curve that is the market-weighted average (MWA) quality of high quality bonds. Spot Rates.  The spot rates for any maturity is the yield on a bond that provides a single payment at that maturity. This is a zero coupon bond. Because each spot rate pertains to a single cashflow, it is the relevant interest rate concept for discounting a pension liability at the same maturity.
#
# economy: Get Forecasted GDP Data. Get Nominal GDP Data. Get Real GDP Data. Get the upcoming, or historical, economic calendar of global events. Get Consumer Price Index (CPI).  Returns either the rescaled index value, or a rate of change (inflation). Get Market Risk Premium by country. Balance of Payments Reports. Search for FRED series or economic releases by ID or string.  This does not return the observation values, only the metadata. Use this function to find series IDs for `fred_series()`. Get data by series ID from FRED. Get Money Measures (M1/M2 and components).  The Federal Reserve publishes as part of the H.6 Release. Get global unemployment data. Use the composite leading indicator (CLI).  It is designed to provide early signals of turning points in business cycles showing fluctuation of the economic activity around its long term potential level.  CLIs show short-term economic movements in qualitative rather than quantitative terms. Get Short-term interest rates.  They are the rates at which short-term borrowings are effected between financial institutions or the rate at which short-term government paper is issued or traded in the market.  Short-term interest rates are generally averages of daily rates, measured as a percentage. Short-term interest rates are based on three-month money market rates where available. Typical standardised names are "money market rate" and "treasury bill rate". Get Long-term interest rates that refer to government bonds maturing in ten years.  Rates are mainly determined by the price charged by the lender, the risk from the borrower and the fall in the capital value. Long-term interest rates are generally averages of daily rates, measured as a percentage. These interest rates are implied by the prices at which the government bonds are traded on financial markets, not the interest rates at which the loans were issued. In all cases, they refer to bonds whose capital repayment is guaranteed by governments. Long-term interest rates are one of the determinants of business investment. Low long-term interest rates encourage investment in new equipment and high interest rates discourage it. Investment is, in turn, a major source of economic growth. Query the Geo Fred API for regional economic data by series group.  The series group ID is found by using `fred_search` and the `series_id` parameter. Get a profile of country statistics and economic indicators. Get the available economic indicators for a provider. Get economic indicators by country and indicator. Get the balance sheet holdings of a central bank. Get the Share Price Index by country from the OECD Short-Term Economics Statistics. Get the House Price Index by country from the OECD Short-Term Economics Statistics. Get immediate interest rates by country. Get retail prices for common items.
#
# crypto: Get historical price data for cryptocurrency pair(s) within a provider. Search available cryptocurrency pairs within a provider.
#
#
# First level answer: derivatives
# Current Trail: ['derivatives'] and level: 2
# Subsequent level 2 string to LLM: futures: Historical futures prices. Futures Term Structure, current or historical.
#
# options: Get the complete options chain for a ticker.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for the current price of Gold futures, which falls under the category of Historical futures prices.',
#     output='futures'
# )
# Current Trail: ['derivatives-->futures'] and level: 3
# Subsequent level 3 string to LLM: historical: Historical futures prices.
#
# curve: Futures Term Structure, current or historical.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for the current price of Gold futures, which falls under the category of current information rather than historical data.',
#     output='curve'
# )
# Current Trail: ['derivatives-->futures-->curve'] and level: 4
# [{'ids': ['id177'], 'embeddings': None, 'metadatas': [{'function_call': "{'name': 'obb-derivatives-futures-curve_yfinance', 'description': 'Futures Term Structure, current or historical.', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for.', 'default': '', 'choices': None}, 'date': {'type': 'string', 'description': 'A specific date to get data for.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: y, f, i, n, a, n, c, e.', 'default': None, 'type': 'string', 'enum': ['yfinance']}}, 'required': ['symbol', 'provider']}}", 'node_name': 'obb-derivatives-futures-curve_yfinance', 'provider_source': 'yfinance', 'trail': 'derivatives-->futures-->curve', 'type': 'provider_function'}], 'documents': ['empty'], 'uris': None, 'data': None}]
# code="from openbb import obb\ndf=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> No results found. Try adjusting the query parameters.\n'
# code="from openbb import obb\ndf=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> No results found. Try adjusting the query parameters.\n'
# code="from openbb import obb\ndf=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> No results found. Try adjusting the query parameters.\n'
# code="from openbb import obb\ndf=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> No results found. Try adjusting the query parameters.\n'
# Couldn't resolve the error OpenBBError:
# [Error] -> No results found. Try adjusting the query parameters.
#  with the code from openbb import obb
# df=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')
# print(df.tail(100).to_markdown(index=False))
#
# >>>>>>>> EXECUTING FUNCTION function_calling_openbb...
# First level string: crypto: Get historical price data for cryptocurrency pair(s) within a provider. Search available cryptocurrency pairs within a provider.
#
# currency: Currency Historical Price. Currency historical data.  Currency historical prices refer to the past exchange rates of one currency against another over a specific period. This data provides insight into the fluctuations and trends in the foreign exchange market, helping analysts, traders, and economists understand currency performance, evaluate economic health, and make predictions about future movements. Currency Search.  Search available currency pairs. Currency pairs are the national currencies from two countries coupled for trading on the foreign exchange (FX) marketplace. Both currencies will have exchange rates on which the trade will have its position basis. All trading within the forex market, whether selling, buying, or trading, will take place through currency pairs. (ref: Investopedia) Major currency pairs include pairs such as EUR/USD, USD/JPY, GBP/USD, etc. Snapshots of currency exchange rates from an indirect or direct perspective of a base currency.
#
# fixedincome: Ameribor.  Ameribor (short for the American interbank offered rate) is a benchmark interest rate that reflects the true cost of short-term interbank borrowing. This rate is based on transactions in overnight unsecured loans conducted on the American Financial Exchange (AFX). Sterling Overnight Index Average.  SONIA (Sterling Overnight Index Average) is an important interest rate benchmark. SONIA is based on actual transactions and reflects the average of the interest rates that banks pay to borrow sterling overnight from other financial institutions and other institutional investors. Interest on Reserve Balances.  Get Interest Rate on Reserve Balances data A bank rate is the interest rate a nation's central bank charges to its domestic banks to borrow money. The rates central banks charge are set to stabilize the economy. In the United States, the Federal Reserve System's Board of Governors set the bank rate, also known as the discount rate. Fed Funds Rate.  Get Effective Federal Funds Rate data. A bank rate is the interest rate a nation's central bank charges to its domestic banks to borrow money. The rates central banks charge are set to stabilize the economy. In the United States, the Federal Reserve System's Board of Governors set the bank rate, also known as the discount rate. Fed Funds Rate Projections.  The projections for the federal funds rate are the value of the midpoint of the projected appropriate target range for the federal funds rate or the projected appropriate target level for the federal funds rate at the end of the specified calendar year or over the longer run. Euro Short-Term Rate.  The euro short-term rate (€STR) reflects the wholesale euro unsecured overnight borrowing costs of banks located in the euro area. The €STR is published on each TARGET2 business day based on transactions conducted and settled on the previous TARGET2 business day (the reporting date “T”) with a maturity date of T+1 which are deemed to have been executed at arm’s length and thus reflect market rates in an unbiased way. European Central Bank Interest Rates.  The Governing Council of the ECB sets the key interest rates for the euro area:  - The interest rate on the main refinancing operations (MRO), which provide the bulk of liquidity to the banking system. - The rate on the deposit facility, which banks may use to make overnight deposits with the Eurosystem. - The rate on the marginal lending facility, which offers overnight credit to banks from the Eurosystem. Discount Window Primary Credit Rate.  A bank rate is the interest rate a nation's central bank charges to its domestic banks to borrow money. The rates central banks charge are set to stabilize the economy. In the United States, the Federal Reserve System's Board of Governors set the bank rate, also known as the discount rate.
#
# derivatives: Get the complete options chain for a ticker. Historical futures prices. Futures Term Structure, current or historical.
#
# equity: Get historical and upcoming initial public offerings (IPOs). Get historical and upcoming dividend payments. Includes dividend amount, ex-dividend and payment dates. Get historical and upcoming stock split operations. Get historical and upcoming company earnings releases. Includes earnings per share (EPS) and revenue data. Get the closest peers for a given company.  Peers consist of companies trading on the same exchange, operating within the same sector and with comparable market capitalizations. Copmare reported company facts and fundamental data points. Get analyst price targets by company. Get historical analyst estimates for earnings and revenue. Get consensus price target and recommendation. Search for specific analysts and get their forecast track record. Get forward sales estimates. Get forward EBITDA estimates. Get forward EPS estimates. Get forward PE estimates. Get the top price gainers in the stock market. Get the top price losers in the stock market. Get the most actively traded stocks based on volume. Get potentially undervalued large cap stocks. Get potentially undervalued growth stocks. Get top small cap stocks based on earnings growth. Get top tech stocks based on revenue and earnings growth. Get the URLs to SEC filings reported to EDGAR database, such as 10-K, 10-Q, 8-K, and more.  SEC filings include Form 10-K, Form 10-Q, Form 8-K, the proxy statement, Forms 3, 4, and 5, Schedule 13, Form 114, Foreign Investment Disclosures and others. The annual 10-K report is required to be filed annually and includes the company's financial statements, management discussion and analysis, and audited financial statements. Get equity valuation multiples for a given company. Get the balance sheet for a given company. Get the growth of a company's balance sheet items over time. Get the cash flow statement for a given company. Get financial statements as reported by the company. Get the growth of a company's cash flow statement items over time. Get historical dividend data for a given company. Get historical earnings per share data for a given company. Get historical employee count data for a given company. Search Intrinio data tags to search in latest or historical attributes. Get the latest value of a data tag from Intrinio. Get the historical values of a data tag from Intrinio. Get the income statement for a given company. Get the growth of a company's income statement items over time. Get fundamental metrics for a given company. Get executive management team data for a given company. Get executive management team compensation for a given company over time. Get an extensive set of financial and accounting ratios for a given company over time. Get the revenue geographic breakdown for a given company over time. Get the revenue breakdown by business segment for a given company over time. Get historical stock splits for a given company. Get earnings call transcripts for a given company. Get the 1 year trailing dividend yield for a given company over time. Get data about major holders for a given company over time. Get data about institutional ownership for a given company over time.
#
#
# First level answer: crypto
# Current Trail: ['crypto'] and level: 2
# Subsequent level 2 string to LLM: price: Get historical price data for cryptocurrency pair(s) within a provider.
#
# search: Search available cryptocurrency pairs within a provider.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for the current price of Bitcoin, which falls under the category of getting the price data for a cryptocurrency pair.',
#     output='price'
# )
# Current Trail: ['crypto-->price'] and level: 3
# [{'ids': ['id159', 'id160', 'id161', 'id162'], 'embeddings': None, 'metadatas': [{'function_call': "{'name': 'obb-crypto-price-historical_fmp', 'description': 'Get historical price data for cryptocurrency pair(s) within a provider. Get it from provider fmp', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for. Can use CURR1-CURR2 or CURR1CURR2 format. Multiple items allowed for provider(s): fmp, polygon, tiingo, yfinance.', 'default': '', 'choices': None}, 'start_date': {'type': 'string', 'description': 'Start date of the data, in YYYY-MM-DD format.', 'default': None, 'choices': None}, 'end_date': {'type': 'string', 'description': 'End date of the data, in YYYY-MM-DD format.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.', 'default': None, 'type': 'string', 'enum': ['fmp']}, 'interval': {'name': 'interval', 'description': 'Time interval of the data to return.', 'default': '1d', 'optional': True, 'choices': None, 'type': 'string', 'enum': ['1m', '5m', '15m', '30m', '1h', '4h', '1d']}}, 'required': ['symbol', 'provider']}}", 'node_name': 'obb-crypto-price-historical_fmp', 'provider_source': 'fmp', 'trail': 'crypto-->price-->historical', 'type': 'provider_function'}, {'function_call': '{\'name\': \'obb-crypto-price-historical_polygon\', \'description\': \'Get historical price data for cryptocurrency pair(s) within a provider. Get it from provider polygon\', \'parameters\': {\'type\': \'object\', \'properties\': {\'symbol\': {\'type\': \'string\', \'description\': \'Symbol to get data for. Can use CURR1-CURR2 or CURR1CURR2 format. Multiple items allowed for provider(s): fmp, polygon, tiingo, yfinance.\', \'default\': \'\', \'choices\': None}, \'start_date\': {\'type\': \'string\', \'description\': \'Start date of the data, in YYYY-MM-DD format.\', \'default\': None, \'choices\': None}, \'end_date\': {\'type\': \'string\', \'description\': \'End date of the data, in YYYY-MM-DD format.\', \'default\': None, \'choices\': None}, \'provider\': {\'description\': \'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: f, m, p.\', \'default\': None, \'type\': \'string\', \'enum\': [\'polygon\']}, \'interval\': {\'name\': \'interval\', \'type\': \'string\', \'description\': \'Time interval of the data to return. The numeric portion of the interval can be any positive integer. The letter portion can be one of the following: s, m, h, d, W, M, Q, Y\', \'default\': \'1d\', \'optional\': True, \'choices\': None}, \'sort\': {\'name\': \'sort\', \'description\': "Sort order of the data. This impacts the results in combination with the \'limit\' parameter. The results are always returned in ascending order by date.", \'default\': \'asc\', \'optional\': True, \'choices\': None, \'type\': \'string\', \'enum\': [\'asc\', \'desc\']}, \'limit\': {\'name\': \'limit\', \'type\': \'integer\', \'description\': \'The number of data entries to return.\', \'default\': 49999, \'optional\': True, \'choices\': None}}, \'required\': [\'symbol\', \'provider\']}}', 'node_name': 'obb-crypto-price-historical_polygon', 'provider_source': 'polygon', 'trail': 'crypto-->price-->historical', 'type': 'provider_function'}, {'function_call': '{\'name\': \'obb-crypto-price-historical_tiingo\', \'description\': \'Get historical price data for cryptocurrency pair(s) within a provider. Get it from provider tiingo\', \'parameters\': {\'type\': \'object\', \'properties\': {\'symbol\': {\'type\': \'string\', \'description\': \'Symbol to get data for. Can use CURR1-CURR2 or CURR1CURR2 format. Multiple items allowed for provider(s): fmp, polygon, tiingo, yfinance.\', \'default\': \'\', \'choices\': None}, \'start_date\': {\'type\': \'string\', \'description\': \'Start date of the data, in YYYY-MM-DD format.\', \' ...
# code="from openbb import obb\ndf=obb.crypto.price.historical(symbol='BTC-USD',provider='fmp',interval='1d')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=0 output='|    open |    high |     low |   close |      volume |    vwap |   adj_close |   change |   change_percent |\n|--------:|--------:|--------:|--------:|------------:|--------:|------------:|---------:|-----------------:|\n| 68354.3 | 68940   | 66562.6 | 67613   | 4.92616e+10 | 67500.1 |     67548.6 |  -741.25 |     -0.0108      |\n| 67600   | 68136.4 | 61506   | 61906.3 | 7.42158e+10 | 64106.4 |     61912.8 | -5693.73 |     -0.0842      |\n| 62022   | 68202   | 60771.1 | 67858.8 | 6.67926e+10 | 64207.7 |     67913.7 |  5836.8  |      0.0941      |\n| 67855.9 | 68280   | 64525   | 65484.7 | 4.44804e+10 | 66510.1 |     65491.4 | -2371.18 |     -0.0349      |\n| 65479   | 66712   | 62201   | 63814.6 | 4.14011e+10 | 64064.7 |     63778.8 | -1664.42 |     -0.0254      |\n| 63814.6 | 66029.1 | 63013.2 | 63998.9 | 2.4739e+10  | 64642.5 |     64062.2 |   184.3  |      0.0028881   |\n| 63998.9 | 67949   | 63785.6 | 67205.2 | 2.72066e+10 | 65686.7 |     67234.2 |  3206.35 |      0.0501      |\n| 67212.7 | 71269.9 | 66381.8 | 69890.4 | 4.27001e+10 | 69156.2 |     69958.8 |  2677.67 |      0.0398      |\n| 69950.1 | 71583   | 69116.8 | 70000.1 | 3.60104e+10 | 70301.5 |     69987.8 |    50    |      0.000714795 |\n| 69996.8 | 71789.9 | 68251   | 69437.3 | 4.08271e+10 | 69637.6 |     69455.3 |  -559.46 |     -0.0079927   |\n| 69437.2 | 71636   | 68800   | 70801.2 | 3.43749e+10 | 70693   |     70745   |  1363.98 |      0.0196      |\n| 70786   | 70941.7 | 69015   | 69903.8 | 2.52309e+10 | 69943.5 |     69892.8 |  -882.25 |     -0.0125      |\n| 69903.7 | 70363.2 | 69569   | 69626.9 | 1.71302e+10 | 69977.2 |     69645.3 |  -276.87 |     -0.0039607   |\n| 69652   | 71444   | 69587.9 | 71291.6 | 2.00509e+10 | 70550.6 |     71333.6 |  1639.56 |      0.0235      |\n| 71291.5 | 71373   | 68055.1 | 69681.1 | 3.48735e+10 | 69438.8 |     69702.1 | -1610.41 |     -0.0226      |\n| 69681.1 | 69711   | 64192   | 65465.1 | 5.07052e+10 | 66052.9 |     65447   | -4215.96 |     -0.0605      |\n| 65472   | 66944.1 | 64500   | 65987.9 | 3.4488e+10  | 66025.3 |     65980.8 |   515.92 |      0.00788     |\n| 65984.1 | 69634   | 65048   | 68527.4 | 3.44395e+10 | 67625   |     68508.8 |  2543.25 |      0.0385      |\n| 68528.5 | 68784   | 65959   | 67856.5 | 3.37482e+10 | 67457.3 |     67837.6 |  -671.95 |     -0.0098054   |\n| 67856.5 | 69693.1 | 67379   | 68919.9 | 1.99678e+10 | 68283.2 |     68896.1 |  1063.38 |      0.0157      |\n| 68908.6 | 70312   | 68820   | 69350.3 | 2.12049e+10 | 69486.1 |     69362.6 |   441.74 |      0.0064105   |\n| 69350.4 | 72777   | 69036   | 71622.5 | 3.72614e+10 | 71576.5 |     71631.4 |  2272.17 |      0.0328      |\n| 71650.1 | 71761.4 | 68200   | 69117   | 3.64269e+10 | 69779   |     69139   | -2533.09 |     -0.0354      |\n| 69115.8 | 71341   | 67463.1 | 70634   | 3.83186e+10 | 69027.3 |     70587.9 |  1518.25 |      0.022       |\n| 70733   | 71444   | 69530   | 70046.4 | 3.01534e+10 | 70394   |     70060.6 |  -686.6  |     -0.0097069   |\n| 70103   | 71291   | 65103   | 67148.6 | 4.41293e+10 | 68209.8 |     67195.9 | -2954.39 |     -0.0421      |\n| 67199.8 | 69100   | 60495   | 64008.1 | 5.28697e+10 | 64796.6 |     63821.5 | -3191.7  |     -0.0475      |\n| 64018.6 | 65909   | 62150   | 65777.1 | 4.90843e+10 | 64133.2 |     65738.7 |  1758.45 |      0.0275      |\n| 65700   | 66928.8 | 62315.1 | 63452.2 | 4.35959e+10 | 64848.3 |     63426.2 | -2247.82 |     -0.0342      |\n| 63441.8 | 64415   | 61551   | 63814.9 | 4.28475e+10 | 62860.5 |     63811.9 |   373.14 |      0.0058816   |\n| 63832.6 | 64534   | 59648.3 | 61279.3 | 4.19152e+10 | 61644.2 |     61276.7 | -2553.3  |     -0.04        |\n| 61284.4 | 64210   | 60816.1 | 63513.8 | 3.60063e+10 | 62791.1 |     63512.8 |  2229.45 |      0.0364      |\n| 63499.5 | 65501   | 59573.3 | 63848.4 | 4.99204e+10 | 63470.1 |     63843.6 |   348.87 |      0.0054941   |\n| 63846   | 65465   | 63121.2 | 64968.9 | 2.30975e+10 | 64393.5 |     64994.4 |  1122.87 |      ...
# Tool Proxy (to Planner Admin):
#
# Tool Proxy (to Planner Admin):
#
# ***** Response from calling tool (call_9JAyQgCP7jEomDQzNwVxtxq0) *****
# null
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# ***** Response from calling tool (call_vkjCZiqWuwLiHZ0UBeufvVtQ) *****
# |    open |    high |     low |   close |      volume |    vwap |   adj_close |   change |   change_percent |
# |--------:|--------:|--------:|--------:|------------:|--------:|------------:|---------:|-----------------:|
# | 68354.3 | 68940   | 66562.6 | 67613   | 4.92616e+10 | 67500.1 |     67548.6 |  -741.25 |     -0.0108      |
# | 67600   | 68136.4 | 61506   | 61906.3 | 7.42158e+10 | 64106.4 |     61912.8 | -5693.73 |     -0.0842      |
# | 62022   | 68202   | 60771.1 | 67858.8 | 6.67926e+10 | 64207.7 |     67913.7 |  5836.8  |      0.0941      |
# | 67855.9 | 68280   | 64525   | 65484.7 | 4.44804e+10 | 66510.1 |     65491.4 | -2371.18 |     -0.0349      |
# | 65479   | 66712   | 62201   | 63814.6 | 4.14011e+10 | 64064.7 |     63778.8 | -1664.42 |     -0.0254      |
# | 63814.6 | 66029.1 | 63013.2 | 63998.9 | 2.4739e+10  | 64642.5 |     64062.2 |   184.3  |      0.0028881   |
# | 63998.9 | 67949   | 63785.6 | 67205.2 | 2.72066e+10 | 65686.7 |     67234.2 |  3206.35 |      0.0501      |
# | 67212.7 | 71269.9 | 66381.8 | 69890.4 | 4.27001e+10 | 69156.2 |     69958.8 |  2677.67 |      0.0398      |
# | 69950.1 | 71583   | 69116.8 | 70000.1 | 3.60104e+10 | 70301.5 |     69987.8 |    50    |      0.000714795 |
# | 69996.8 | 71789.9 | 68251   | 69437.3 | 4.08271e+10 | 69637.6 |     69455.3 |  -559.46 |     -0.0079927   |
# | 69437.2 | 71636   | 68800   | 70801.2 | 3.43749e+10 | 70693   |     70745   |  1363.98 |      0.0196      |
# | 70786   | 70941.7 | 69015   | 69903.8 | 2.52309e+10 | 69943.5 |     69892.8 |  -882.25 |     -0.0125      |
# | 69903.7 | 70363.2 | 69569   | 69626.9 | 1.71302e+10 | 69977.2 |     69645.3 |  -276.87 |     -0.0039607   |
# | 69652   | 71444   | 69587.9 | 71291.6 | 2.00509e+10 | 70550.6 |     71333.6 |  1639.56 |      0.0235      |
# | 71291.5 | 71373   | 68055.1 | 69681.1 | 3.48735e+10 | 69438.8 |     69702.1 | -1610.41 |     -0.0226      |
# | 69681.1 | 69711   | 64192   | 65465.1 | 5.07052e+10 | 66052.9 |     65447   | -4215.96 |     -0.0605      |
# | 65472   | 66944.1 | 64500   | 65987.9 | 3.4488e+10  | 66025.3 |     65980.8 |   515.92 |      0.00788     |
# | 65984.1 | 69634   | 65048   | 68527.4 | 3.44395e+10 | 67625   |     68508.8 |  2543.25 |      0.0385      |
# | 68528.5 | 68784   | 65959   | 67856.5 | 3.37482e+10 | 67457.3 |     67837.6 |  -671.95 |     -0.0098054   |
# | 67856.5 | 69693.1 | 67379   | 68919.9 | 1.99678e+10 | 68283.2 |     68896.1 |  1063.38 |      0.0157      |
# | 68908.6 | 70312   | 68820   | 69350.3 | 2.12049e+10 | 69486.1 |     69362.6 |   441.74 |      0.0064105   |
# | 69350.4 | 72777   | 69036   | 71622.5 | 3.72614e+10 | 71576.5 |     71631.4 |  2272.17 |      0.0328      |
# | 71650.1 | 71761.4 | 68200   | 69117   | 3.64269e+10 | 69779   |     69139   | -2533.09 |     -0.0354      |
# | 69115.8 | 71341   | 67463.1 | 70634   | 3.83186e+10 | 69027.3 |     70587.9 |  1518.25 |      0.022       |
# | 70733   | 71444   | 69530   | 70046.4 | 3.01534e+10 | 70394   |     70060.6 |  -686.6  |     -0.0097069   |
# | 70103   | 71291   | 65103   | 67148.6 | 4.41293e+10 | 68209.8 |     67195.9 | -2954.39 |     -0.0421      |
# | 67199.8 | 69100   | 60495   | 64008.1 | 5.28697e+10 | 64796.6 |     63821.5 | -3191.7  |     -0.0475      |
# | 64018.6 | 65909   | 62150   | 65777.1 | 4.90843e+10 | 64133.2 |     65738.7 |  1758.45 |      0.0275      |
# | 65700   | 66928.8 | 62315.1 | 63452.2 | 4.35959e+10 | 64848.3 |     63426.2 | -2247.82 |     -0.0342      |
# | 63441.8 | 64415   | 61551   | 63814.9 | 4.28475e+10 | 62860.5 |     63811.9 |   373.14 |      0.0058816   |
# | 63832.6 | 64534   | 59648.3 | 61279.3 | 4.19152e+10 | 61644.2 |     61276.7 | -2553.3  |     -0.04        |
# | 61284.4 | 64210   | 60816.1 | 63513.8 | 3.60063e+10 | 62791.1 |     63512.8 |  2229.45 |      0.0364      |
# | 63499.5 | 65501   | 59573.3 | 63848.4 | 4.99204e+10 | 63470.1 |     63843.6 |   348.87 |      0.0054941   |
# | 63846   | 65465   | 63121.2 | 64968.9 | 2.30975e+10 | 64393.5 |     64994.4 |  1122.87 |      0.0176      |
# | 64993.8 | 65756   | 64250   | 64952.9 | 2.05066e+10 | 64954.2 |     64926.6 |   -40.88 |     -0.000628983 |
# | 64953   | 68158   | 64520   | 66859.2 | 2.82827e+10 | 66153.6 |     66837.7 |  1906.17 |      0.0293      |
# | 66831.4 | 67253   | 65807   | 66418   | 2.4311e+10  | 66532.5 |     66407.3 |  -413.4  |     -0.0061857   |
# | 66419.8 | 67153   | 63542.6 | 64255.8 | 3.02767e+10 | 65202.5 |     64276.9 | -2164.02 |     -0.0326      |
# | 64252.4 | 65381   | 62743.5 | 64484.5 | 3.21558e+10 | 64094   |     64481.7 |   232.1  |      0.0036123   |
# | 64489.1 | 64839   | 63287.8 | 63742.4 | 2.41394e+10 | 64044.7 |     63755.3 |  -746.71 |     -0.0116      |
# | 63750.8 | 64029   | 62389   | 63425   | 1.95308e+10 | 63037.7 |     63419.1 |  -325.8  |     -0.0051105   |
# | 63425.1 | 64470   | 62743.8 | 63108.9 | 1.73348e+10 | 63609.2 |     63113.2 |  -316.16 |     -0.0049848   |
# | 63114.1 | 64304   | 61741   | 63844.8 | 2.66359e+10 | 62746   |     63841.1 |   730.75 |      0.0116      |
# | 63822.1 | 64800   | 59040.3 | 60622.1 | 3.78408e+10 | 61053.1 |     60636.9 | -3200    |     -0.0501      |
# | 60610   | 60991   | 56378   | 58265.6 | 4.84398e+10 | 57898.3 |     58254   | -2344.41 |     -0.0387      |
# | 58267.8 | 59767   | 56903.8 | 59071.9 | 3.27118e+10 | 58552   |     59123.4 |   804.08 |      0.0138      |
# | 59113.2 | 63444   | 58821.1 | 62913   | 3.3172e+10  | 61133   |     62889.8 |  3799.83 |      0.0643      |
# | 62925.8 | 64644   | 62550.4 | 63902.9 | 2.06205e+10 | 63518.2 |     63891.5 |   977.08 |      0.0155      |
# | 63898   | 64801   | 62908.3 | 64023.4 | 1.82962e+10 | 63845.5 |     64031.1 |   125.45 |      0.0019633   |
# | 64067.5 | 65628   | 62704.5 | 63164.1 | 2.86979e+10 | 63824.5 |     63161.9 |  -903.44 |     -0.0141      |
# | 63161.7 | 64480   | 62252.6 | 62315.8 | 2.59307e+10 | 63429.4 |     62334.8 |  -845.94 |     -0.0134      |
# | 62325   | 63112   | 60851   | 61169.5 | 2.60882e+10 | 62125.3 |     61187.9 | -1155.47 |     -0.0185      |
# | 61172.1 | 63529   | 60601.6 | 63073.6 | 2.54533e+10 | 61904.4 |     63050   |  1901.47 |      0.0311      |
# | 63052   | 63612   | 60150   | 60787.5 | 2.7805e+10  | 61550.8 |     60792.8 | -2264.53 |     -0.0359      |
# | 60790.8 | 61588   | 60450.1 | 60805   | 1.38423e+10 | 60940.4 |     60793.7 |    14.2  |      0.000233588 |
# | 60805   | 61962   | 60576.1 | 61453   | 1.38005e+10 | 61245.7 |     61448.4 |   648.02 |      0.0107      |
# | 61444.6 | 63540   | 60738.5 | 62932.4 | 2.78892e+10 | 62522.5 |     62901.4 |  1487.77 |      0.0242      |
# | 62910   | 63175   | 61000   | 61539.8 | 2.81863e+10 | 62078.7 |     61552.8 | -1370.16 |     -0.0218      |
# | 61545.8 | 66500   | 61299.6 | 66244.7 | 3.98152e+10 | 64615.1 |     66267.5 |  4698.89 |      0.0763      |
# | 66233.1 | 66799   | 64557   | 65252.2 | 3.15731e+10 | 65754.8 |     65231.6 |  -980.92 |     -0.0148      |
# | 65228.4 | 67618   | 65113.5 | 67046.3 | 2.80313e+10 | 66576.1 |     67051.9 |  1817.93 |      0.0279      |
# | 67043.6 | 67473   | 66598   | 66923.9 | 1.67123e+10 | 66974.7 |     66940.8 |  -119.73 |     -0.0017859   |
# | 66920.1 | 67984   | 65852   | 66262.4 | 1.92491e+10 | 66864.2 |     66278.4 |  -657.7  |     -0.0098281   |
# | 66262.5 | 71560.9 | 66057   | 71432.2 | 4.38507e+10 | 68757   |     71448.2 |  5169.67 |      0.078       |
# | 71432.2 | 71980   | 69146   | 70145.1 | 4.6932e+10  | 70560.6 |     70136.5 | -1287.06 |     -0.018       |
# | 70145.1 | 70668   | 68725.2 | 69109.9 | 3.28026e+10 | 69748.2 |     69122.3 | -1035.17 |     -0.0148      |
# | 69144.1 | 70500   | 66250   | 67940.4 | 4.18957e+10 | 68230.4 |     67929.6 | -1203.65 |     -0.0174      |
# | 67947   | 69308   | 66587.9 | 68547.8 | 2.91973e+10 | 68161.1 |     68526.1 |   600.8  |      0.0088422   |
# | 68541   | 69635   | 68487.4 | 69289.7 | 1.54731e+10 | 69031.9 |     69265.9 |   748.67 |      0.0109      |
# | 69278.7 | 69588   | 67971.1 | 68473.7 | 1.56284e+10 | 68887.4 |     68518.1 |  -804.98 |     -0.0116      |
# | 68474.4 | 70679   | 68210.1 | 69368.7 | 2.5871e+10  | 69475.1 |     69394.6 |   894.32 |      0.0131      |
# | 69377.8 | 69597   | 67194.6 | 68322   | 3.27223e+10 | 68146.7 |     68296.2 | -1055.82 |     -0.0152      |
# | 68325   | 68971   | 67081.7 | 67569.4 | 2.67071e+10 | 67787.7 |     67578.1 |  -755.55 |     -0.0111      |
# | 67575.4 | 69550   | 67092.9 | 68338.6 | 2.95097e+10 | 68433.3 |     68365   |   763.18 |      0.0113      |
# | 68365   | 69028   | 66584.5 | 67472.4 | 2.73873e+10 | 67688   |     67491.4 |  -892.59 |     -0.0131      |
# | 67498.1 | 67890   | 67371.3 | 67719.3 | 1.16415e+10 | 67659.8 |     67706.9 |   221.19 |      0.003277    |
# | 67717.2 | 68444   | 67260   | 67735.5 | 1.71106e+10 | 67837.2 |     67751.6 |    18.32 |      0.000270537 |
# | 67731.1 | 70295.8 | 67568   | 68791   | 3.24013e+10 | 69164.4 |     68804.8 |  1059.86 |      0.0156      |
# | 68800   | 71108.9 | 68542.4 | 70542.3 | 3.31497e+10 | 70132.9 |     70567.8 |  1742.32 |      0.0253      |
# | 70558.7 | 71804.1 | 70356.5 | 71121.1 | 3.28108e+10 | 71104.6 |     71082.8 |   562.41 |      0.0079708   |
# | 71116.3 | 71651   | 70094   | 70773.6 | 2.52232e+10 | 70997.5 |     70757.2 |  -342.66 |     -0.0048183   |
# | 70752.1 | 71974   | 68298.6 | 69394   | 3.61884e+10 | 70253.7 |     69342.6 | -1358.1  |     -0.0192      |
# | 69317.1 | 69618   | 69126.2 | 69304.1 | 1.42622e+10 | 69370.2 |     69305.8 |   -13.05 |     -0.000188265 |
# | 69291.5 | 69848.9 | 69101   | 69649.9 | 1.3534e+10  | 69523.1 |     69648   |   358.4  |      0.0051724   |
# | 69649.9 | 70187.5 | 69141.5 | 69497.7 | 2.05977e+10 | 69630.5 |     69512.3 |  -152.17 |     -0.0021848   |
# | 69522.2 | 69558.7 | 66018.7 | 67316.5 | 3.71161e+10 | 67339.9 |     67332   | -2205.67 |     -0.0317      |
# | 67330   | 70037   | 66883.3 | 68248.6 | 3.44979e+10 | 68667.3 |     68241.2 |   918.6  |      0.0136      |
# | 68248.6 | 68474.5 | 66200   | 66756.5 | 2.89552e+10 | 67212.5 |     66756.4 | -1492.09 |     -0.0219      |
# | 66776   | 67370   | 65005   | 66004.4 | 2.74039e+10 | 66106.6 |     66011.1 |  -771.61 |     -0.0116      |
# | 65992.1 | 66442   | 65794.7 | 66192   | 1.41213e+10 | 66165.3 |     66191   |   199.9  |      0.0030292   |
# | 66198.1 | 66947   | 65999   | 66628.8 | 1.32811e+10 | 66515.1 |     66639   |   430.65 |      0.0065055   |
# | 66630   | 67302   | 65050   | 66481.8 | 3.00064e+10 | 66232.9 |     66490.3 |  -148.19 |     -0.0022241   |
# | 66487.7 | 66623   | 64010   | 65152.8 | 3.94813e+10 | 65041.9 |     65140.7 | -1334.9  |     -0.0201      |
# | 65169.7 | 65820   | 64635.5 | 64943.8 | 2.11034e+10 | 65155.7 |     64960.3 |  -225.91 |     -0.0034665   |
# | 64949.1 | 66585   | 64500   | 64841.5 | 2.56411e+10 | 65309.7 |     64828.7 |  -107.64 |     -0.0016573   |
# | 64833.3 | 65196   | 63300.9 | 64087.9 | 2.61882e+10 | 63991.2 |     64096.2 |  -745.4  |     -0.0115      |
# | 64088   | 64613   | 63910   | 64235   | 9.8582e+09  | 64316   |     64252.6 |   147.01 |      0.0022939   |
# | 64253   | 64618   | 63125.8 | 63171.4 | 1.11705e+10 | 63991.6 |     63180.8 | -1081.57 |     -0.0168      |
# | 63169.4 | 63461   | 58994.8 | 59431.6 | 3.92652e+10 | 61207.2 |     59449.3 | -3737.74 |     -0.0592      |
# | 60266.3 | 61650   | 60217.4 | 61226.2 | 4.33997e+10 | 61031.2 |     61226.2 |   959.97 |      0.0159288   |
#
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# I encountered an issue retrieving the data on Gold futures. However, I successfully gathered recent price data for Bitcoin:
#
# #### Bitcoin Price Data:
# - **Open**: $68,354.3
# - **High**: $68,940
# - **Low**: $66,562.6
# - **Close**: $67,613
# - **Volume**: $49,261,600,000
# - **VWAP (Volume-Weighted Average Price)**: $67,500.1
# - **Adjusted Close**: $67,548.6
# - **Change**: -$741.25
# - **Change Percent**: -1.08%
#
# Based on this data, Bitcoin has shown some fluctuations but remains within a relatively high range. If you want to attempt retrieving the data for Gold futures again or need further assistance, please let me know.
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# It seems like the data for Bitcoin has been successfully retrieved, providing valuable insights into its recent performance. If you have any further questions or need additional assistance, feel free to ask. Would you like to make another attempt to retrieve the Gold futures data, or is there anything else you need help with?
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# It seems there was a miscommunication in my previous response. Let's clarify the situation.
#
# ### Updated Data Review:
#
# #### Bitcoin Price Data:
# - The details provided were comprehensive, showing the closing prices, high, low, and changes over recent sessions. Bitcoin displayed significant price movements, demonstrating the volatility characteristic of cryptocurrencies.
#
# Given your initial query, if you'd like, I can attempt to fetch the Gold futures data again or help you with another inquiry. Please specify how you would like to proceed, whether retrieving Gold futures data or exploring another financial matter!
#
# --------------------------------------------------------------------------------
# Tool Proxy (to Planner Admin):
#
# Thank you for the updated clarification regarding the Bitcoin price data review.
#
# If you would like to proceed with attempting to retrieve the Gold futures data again, please let me know so I can gather the latest information for you. Alternatively, if you have any other specific inquiries or topics you'd like to explore, feel free to provide the details, and I will assist you accordingly. Just let me know how you would like to proceed!
#
# --------------------------------------------------------------------------------
# Planner Admin (to Tool Proxy):
#
# It seems there was a misunderstanding. I will reattempt to fetch the latest information on Gold futures for you. Please hold on a moment while I retrieve the data.
# ***** Suggested tool call (call_QOcoj5dvwaJHa0IHr0huNcR7): function_calling_openbb *****
# Arguments:
# {"question":"latest price of Gold futures"}
# ****************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION function_calling_openbb...
# First level string: derivatives: Get the complete options chain for a ticker. Historical futures prices. Futures Term Structure, current or historical.
#
# currency: Currency Historical Price. Currency historical data.  Currency historical prices refer to the past exchange rates of one currency against another over a specific period. This data provides insight into the fluctuations and trends in the foreign exchange market, helping analysts, traders, and economists understand currency performance, evaluate economic health, and make predictions about future movements. Currency Search.  Search available currency pairs. Currency pairs are the national currencies from two countries coupled for trading on the foreign exchange (FX) marketplace. Both currencies will have exchange rates on which the trade will have its position basis. All trading within the forex market, whether selling, buying, or trading, will take place through currency pairs. (ref: Investopedia) Major currency pairs include pairs such as EUR/USD, USD/JPY, GBP/USD, etc. Snapshots of currency exchange rates from an indirect or direct perspective of a base currency.
#
# fixedincome: Treasury Constant Maturity.  Get data for 10-Year Treasury Constant Maturity Minus Selected Treasury Constant Maturity. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities.Select Treasury Constant Maturity.  Get data for Selected Treasury Constant Maturity Minus Federal Funds Rate Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Select Treasury Bill.  Get Selected Treasury Bill Minus Federal Funds Rate. Constant maturity is the theoretical value of a U.S. Treasury that is based on recent values of auctioned U.S. Treasuries. The value is obtained by the U.S. Treasury on a daily basis through interpolation of the Treasury yield curve which, in turn, is based on closing bid-yields of actively-traded Treasury securities. Get yield curve data by country and date. Government Treasury Rates. ICE BofA US Corporate Bond Indices.  The ICE BofA US Corporate Index tracks the performance of US dollar denominated investment grade corporate debt publicly issued in the US domestic market. Qualifying securities must have an investment grade rating (based on an average of Moody’s, S&P and Fitch), at least 18 months to final maturity at the time of issuance, at least one year remaining term to final maturity as of the rebalance date, a fixed coupon schedule and a minimum amount outstanding of $250 million. The ICE BofA US Corporate Index is a component of the US Corporate Master Index. Moody Corporate Bond Index.  Moody's Aaa and Baa are investment bonds that acts as an index of the performance of all bonds given an Aaa or Baa rating by Moody's Investors Service respectively. These corporate bonds often are used in macroeconomics as an alternative to the federal ten-year Treasury Bill as an indicator of the interest rate. High Quality Market Corporate Bond.  The HQM yield curve represents the high quality corporate bond market, i.e., corporate bonds rated AAA, AA, or A.  The HQM curve contains two regression terms. These terms are adjustment factors that blend AAA, AA, and A bonds into a single HQM yield curve that is the market-weighted average (MWA) quality of high quality bonds. Spot Rates.  The spot rates for any maturity is the yield on a bond that provides a single payment at that maturity. This is a zero coupon bond. Because each spot rate pertains to a single cashflow, it is the relevant interest rate concept for discounting a pension liability at the same maturity.
#
# economy: Get Forecasted GDP Data. Get Nominal GDP Data. Get Real GDP Data. Get the upcoming, or historical, economic calendar of global events. Get Consumer Price Index (CPI).  Returns either the rescaled index value, or a rate of change (inflation). Get Market Risk Premium by country. Balance of Payments Reports. Search for FRED series or economic releases by ID or string.  This does not return the observation values, only the metadata. Use this function to find series IDs for `fred_series()`. Get data by series ID from FRED. Get Money Measures (M1/M2 and components).  The Federal Reserve publishes as part of the H.6 Release. Get global unemployment data. Use the composite leading indicator (CLI).  It is designed to provide early signals of turning points in business cycles showing fluctuation of the economic activity around its long term potential level.  CLIs show short-term economic movements in qualitative rather than quantitative terms. Get Short-term interest rates.  They are the rates at which short-term borrowings are effected between financial institutions or the rate at which short-term government paper is issued or traded in the market.  Short-term interest rates are generally averages of daily rates, measured as a percentage. Short-term interest rates are based on three-month money market rates where available. Typical standardised names are "money market rate" and "treasury bill rate". Get Long-term interest rates that refer to government bonds maturing in ten years.  Rates are mainly determined by the price charged by the lender, the risk from the borrower and the fall in the capital value. Long-term interest rates are generally averages of daily rates, measured as a percentage. These interest rates are implied by the prices at which the government bonds are traded on financial markets, not the interest rates at which the loans were issued. In all cases, they refer to bonds whose capital repayment is guaranteed by governments. Long-term interest rates are one of the determinants of business investment. Low long-term interest rates encourage investment in new equipment and high interest rates discourage it. Investment is, in turn, a major source of economic growth. Query the Geo Fred API for regional economic data by series group.  The series group ID is found by using `fred_search` and the `series_id` parameter. Get a profile of country statistics and economic indicators. Get the available economic indicators for a provider. Get economic indicators by country and indicator. Get the balance sheet holdings of a central bank. Get the Share Price Index by country from the OECD Short-Term Economics Statistics. Get the House Price Index by country from the OECD Short-Term Economics Statistics. Get immediate interest rates by country. Get retail prices for common items.
#
# crypto: Get historical price data for cryptocurrency pair(s) within a provider. Search available cryptocurrency pairs within a provider.
#
#
# First level answer: derivatives
# Current Trail: ['derivatives'] and level: 2
# Subsequent level 2 string to LLM: futures: Historical futures prices. Futures Term Structure, current or historical.
#
# options: Get the complete options chain for a ticker.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for the current price of Gold futures, which falls under the category of Historical futures prices.',
#     output='futures'
# )
# Current Trail: ['derivatives-->futures'] and level: 3
# Subsequent level 3 string to LLM: historical: Historical futures prices.
#
# curve: Futures Term Structure, current or historical.
#
#
# LLM Answer: Prediction(
#     rationale='produce the output. We are looking for the current price of Gold futures, which falls under the category of current information rather than historical data.',
#     output='curve'
# )
# Current Trail: ['derivatives-->futures-->curve'] and level: 4
# [{'ids': ['id177'], 'embeddings': None, 'metadatas': [{'function_call': "{'name': 'obb-derivatives-futures-curve_yfinance', 'description': 'Futures Term Structure, current or historical.', 'parameters': {'type': 'object', 'properties': {'symbol': {'type': 'string', 'description': 'Symbol to get data for.', 'default': '', 'choices': None}, 'date': {'type': 'string', 'description': 'A specific date to get data for.', 'default': None, 'choices': None}, 'provider': {'description': 'The provider to use, by default None. If None, the priority list configured in the settings is used. Default priority: y, f, i, n, a, n, c, e.', 'default': None, 'type': 'string', 'enum': ['yfinance']}}, 'required': ['symbol', 'provider']}}", 'node_name': 'obb-derivatives-futures-curve_yfinance', 'provider_source': 'yfinance', 'trail': 'derivatives-->futures-->curve', 'type': 'provider_function'}], 'documents': ['empty'], 'uris': None, 'data': None}]
# code="from openbb import obb\ndf=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> No results found. Try adjusting the query parameters.\n'
# code="from openbb import obb\ndf=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> No results found. Try adjusting the query parameters.\n'
# code="from openbb import obb\ndf=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> No results found. Try adjusting the query parameters.\n'
# code="from openbb import obb\ndf=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')\nprint(df.tail(100).to_markdown(index=False))" language='python'
# exit_code=1 output='Error during execution: OpenBBError: \n[Error] -> No results found. Try adjusting the query parameters.\n'
# Couldn't resolve the error OpenBBError:
# [Error] -> No results found. Try adjusting the query parameters.
#  with the code from openbb import obb
# df=obb.derivatives.futures.curve(symbol='GC=F',provider='yfinance')
# print(df.tail(100).to_markdown(index=False))
# Tool Proxy (to Planner Admin):
#
# Tool Proxy (to Planner Admin):
#
# ***** Response from calling tool (call_QOcoj5dvwaJHa0IHr0huNcR7) *****
# null
# **********************************************************************
#
# --------------------------------------------------------------------------------
