# %% [markdown]
# # Trading Strategist Agent with BackTrader

# %% [markdown]
# In this demo, we introduce an agent workflow that write trading strategy and refine it throught backtesting using the **BackTrader** library.

# %%
import os
import autogen
from autogen.cache import Cache

from finrobot.functional.quantitative import BackTraderUtils
from finrobot.toolkits import register_toolkits, register_code_writing
from textwrap import dedent

# %%
config_list = autogen.config_list_from_json(
    "../OAI_CONFIG_LIST",
    filter_dict={
        "model": ["gpt-4-0125-preview"],
    },
)
llm_config = {
    "config_list": config_list,
    "timeout": 120,
    "temperature": 0
}

from finrobot.functional.coding import default_path

# Intermediate strategy modules will be saved in this directory
work_dir = default_path
os.makedirs(work_dir, exist_ok=True)

# %% [markdown]
# For this task, we need:
# - A normal llm agent as data provider: Call charting functions and provide instructions for multimodal agent
# - A multimodal agent as market analyst: Extract the necessary information from the chart and analyze the future trend of this stock.
# - A user proxy to execute python functions and control the conversations.

# %%
strategist = autogen.AssistantAgent(
    name="Trade_Strategist",
    system_message=dedent("""
        You are a trading strategist known for your expertise in developing sophisticated trading algorithms. 
        Your task is to utilize the existing SmaCross strategy (for which you don't need to write code, just specifying params) 
        or leverage your coding skills to create a customized trading strategy using the BackTrader Python library, and save it as a Python module. 
        You must provide trading strategies based on user demands and optimize them according to backtesting results.
        However, if backtesting came back with failed attempts, you should help with the examination and fix bugs.
        Reply TERMINATE to executer when the strategy is ready to be tested.
        """),
    llm_config=llm_config,
)
strategist_executor = autogen.UserProxyAgent(
    name="Trade_Strategist_Executor",
    human_input_mode="NEVER",
    is_termination_msg=lambda x: x.get("content", "") and x.get("content", "").find("TERMINATE") >= 0,
    code_execution_config={
        "last_n_messages": 1,
        "work_dir": work_dir,
        "use_docker": False,
    },  # Please set use_docker=True if docker is available to run the generated code. Using docker is safer than running the generated code directly.
)
register_code_writing(strategist, strategist_executor)

analyst = autogen.AssistantAgent(
    name="Backtesting_Analyst",
    system_message=dedent("""
        You are a backtesting analyst with a strong command of quantitative analysis tools. 
        Your primary role is to employ backtesting tools to rigorously evaluate the efficacy of designated trading strategies. 
        Upon completing your analysis, you are responsible for compiling and reporting the results in a clear and comprehensive manner, providing key insights that will inform further strategy development and refinement.
        However, if not all necessary information needed for backtesting is provided, you can skip backtesting and ask the strategist for additional details.
        Reply TERMINATE when the backtesting and analysis is complete.
        """),
    llm_config=llm_config,
)
analyst_executor = autogen.UserProxyAgent(
    name="Backtesting_Analyst_Executor",
    human_input_mode="NEVER",
    is_termination_msg=lambda x: x.get("content", "") and x.get("content", "").find("TERMINATE") >= 0,
    code_execution_config={
        "last_n_messages": 1,
        "work_dir": work_dir,
        "use_docker": False,
    },  # Please set use_docker=True if docker is available to run the generated code. Using docker is safer than running the generated code directly.
)
register_toolkits([BackTraderUtils.back_test], analyst, analyst_executor)

# %%
def reflection_message_analyst(recipient, messages, sender, config):
    print("Reflecting strategist's response ...")
    last_msg = recipient.chat_messages_for_summary(sender)[-1]['content']
    return "Message from Trade Strategist is as follows:" + last_msg + "\n\nIf the strategist has completed his work properly, he should have designated a predefined trading strategy or saved a strategy he defined as a Python module. " \
        "Based on his information, conduct a backtest on the specified stock and strategy, and report your backtesting results back to the strategist."

def reflection_message_strategist(recipient, messages, sender, config):
    print("Reflecting analyst's response ...")
    last_msg = recipient.chat_messages_for_summary(sender)[-1]['content']
    return "Message from Backtesting Analyst is as follows:" + last_msg + "\n\nIf the analyst has completed his work properly, he should have completed the backtesting for the specified strategy and reported the results. " \
        "Based on the backtesting results, assess whether the current strategy meets the requirements. If the current strategy still does not meet the requirements, or if you believe that other strategies need to be tested, " \
        "continue to refine or provide new strategies, and then resubmit your backtesting requirements to the analyst."

user_proxy = autogen.UserProxyAgent(
    name="User_Proxy",
    is_termination_msg=lambda x: x.get("content", "") and x.get("content", "").endswith("TERMINATE"),
    human_input_mode="NEVER",
    max_consecutive_auto_reply=10,
    code_execution_config=False         # User Proxy dont need to execute code here
)
user_proxy.register_nested_chats(
    [
        {
            "sender": analyst_executor,
            "recipient": analyst,
            "message": reflection_message_analyst,
            "max_turns": 2,
            "summary_method": "last_msg",
        }
    ],
    trigger=[strategist, strategist_executor],
)
user_proxy.register_nested_chats(
    [
        {
            "sender": strategist_executor,
            "recipient": strategist,
            "message": reflection_message_strategist,
            "max_turns": 5,
            "summary_method": "last_msg",
        }
    ],
    trigger=[analyst, analyst_executor],
)

# %% [markdown]
# To prevent unexpected chat sequence arrangements in group chats, we opt for manual orchestration for this task. After the data provider supplies the data, the user proxy summarizes it and then presents it to the Multimodal market analyst for analysis.

# %%
company = "Microsoft"
start_date = "2023-01-01"
end_date = "2024-01-01"

task = dedent(f"""
    Based on {company}'s stock data from {start_date} to {end_date}, develop a trading strategy that performs well on this stock. 
    You can start your research by providing an SMACross strategy as your baseline, then after receiving the backtest analysis, you might adjust parameters to try again 
    or create a more optimized trade by writing your own python strategy class with BackTrader's `Strategy`. 
    Once you have determined your strategy, you need to inform the backtesting analyst which strategy to use for backtesting on what data. 
    If it is your own written strategy class, you need to report the corresponding module path and class name, as well as any parameters that the strategy might require.
""")

with Cache.disk() as cache:
    user_proxy.initiate_chat(
        recipient=strategist,
        message=task,
        max_turns=10,
        summary_method="last_msg"
    )
# Out:
# User_Proxy (to Trade_Strategist):
#
#
# Based on Microsoft's stock data from 2023-01-01 to 2024-01-01, develop a trading strategy that performs well on this stock.
# You can start your research by providing an SMACross strategy as your baseline, then after receiving the backtest analysis, you might adjust parameters to try again
# or create a more optimized trade by writing your own python strategy class with BackTrader's `Strategy`.
# Once you have determined your strategy, you need to inform the backtesting analyst which strategy to use for backtesting on what data.
# If it is your own written strategy class, you need to report the corresponding module path and class name, as well as any parameters that the strategy might require.
#
#
# --------------------------------------------------------------------------------
# Trade_Strategist (to User_Proxy):
#
# To begin, let's establish a baseline by configuring an SMACross strategy for Microsoft's stock data from 2023-01-01 to 2024-01-01. The SMACross strategy is a simple yet effective trading strategy that involves two Simple Moving Averages (SMA): a short-term SMA and a long-term SMA. The basic principle is to buy when the short-term SMA crosses above the long-term SMA (a bullish signal) and sell when the short-term SMA crosses below the long-term SMA (a bearish signal).
#
# For our initial setup, we'll use commonly applied periods for the SMAs:
# - Short-term SMA: 50 days
# - Long-term SMA: 200 days
#
# These parameters are a starting point and can be adjusted based on backtesting results to optimize performance.
#
# **Strategy to Backtest:**
# - **Strategy Name:** SMACross
# - **Parameters:**
#   - **Short-term SMA period:** 50 days
#   - **Long-term SMA period:** 200 days
# - **Stock Data:** Microsoft (MSFT)
# - **Date Range:** 2023-01-01 to 2024-01-01
#
# This setup will serve as our baseline. After receiving the backtest analysis, we can consider adjusting the SMA periods or potentially developing a more complex strategy using BackTrader's `Strategy` class if the results suggest room for improvement.
#
# Please proceed with backtesting this SMACross strategy with the specified parameters on Microsoft's stock data for the given date range. After reviewing the backtest results, we can make informed decisions on any necessary adjustments or the development of a custom strategy.
#
# --------------------------------------------------------------------------------
# Reflecting strategist's response ...
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Backtesting_Analyst_Executor (to Backtesting_Analyst):
#
# Message from Trade Strategist is as follows:To begin, let's establish a baseline by configuring an SMACross strategy for Microsoft's stock data from 2023-01-01 to 2024-01-01. The SMACross strategy is a simple yet effective trading strategy that involves two Simple Moving Averages (SMA): a short-term SMA and a long-term SMA. The basic principle is to buy when the short-term SMA crosses above the long-term SMA (a bullish signal) and sell when the short-term SMA crosses below the long-term SMA (a bearish signal).
#
# For our initial setup, we'll use commonly applied periods for the SMAs:
# - Short-term SMA: 50 days
# - Long-term SMA: 200 days
#
# These parameters are a starting point and can be adjusted based on backtesting results to optimize performance.
#
# **Strategy to Backtest:**
# - **Strategy Name:** SMACross
# - **Parameters:**
#   - **Short-term SMA period:** 50 days
#   - **Long-term SMA period:** 200 days
# - **Stock Data:** Microsoft (MSFT)
# - **Date Range:** 2023-01-01 to 2024-01-01
#
# This setup will serve as our baseline. After receiving the backtest analysis, we can consider adjusting the SMA periods or potentially developing a more complex strategy using BackTrader's `Strategy` class if the results suggest room for improvement.
#
# Please proceed with backtesting this SMACross strategy with the specified parameters on Microsoft's stock data for the given date range. After reviewing the backtest results, we can make informed decisions on any necessary adjustments or the development of a custom strategy.
#
# If the strategist has completed his work properly, he should have designated a predefined trading strategy or saved a strategy he defined as a Python module. Based on his information, conduct a backtest on the specified stock and strategy, and report your backtesting results back to the strategist.
#
# --------------------------------------------------------------------------------
# Backtesting_Analyst (to Backtesting_Analyst_Executor):
#
# ***** Suggested tool call (call_QAw5T0RvJdzEzgAsUIFUb2lC): back_test *****
# Arguments:
# {"ticker_symbol":"MSFT","start_date":"2023-01-01","end_date":"2024-01-01","strategy":"SMA_CrossOver","params":"{\"fast\": 50, \"slow\": 200}"}
# **************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION back_test...
# [*********************100%%**********************]  1 of 1 completed
# <div id='ea915a77-cf6d-4646-93bb-2ec290af902d'></div>
# <div id='bad2d3bf-790b-41ae-82fc-8e8b5c6db431'></div>
# Backtesting_Analyst_Executor (to Backtesting_Analyst):
#
# Backtesting_Analyst_Executor (to Backtesting_Analyst):
#
# ***** Response from calling tool (call_QAw5T0RvJdzEzgAsUIFUb2lC) *****
# Back Test Finished. Results:
# {'Starting Portfolio Value:': 10000.0, 'Sharpe Ratio': OrderedDict([('sharperatio', None)]), 'Drawdown': AutoOrderedDict([('len', 0), ('drawdown', 0.0), ('moneydown', 0.0), ('max', AutoOrderedDict([('len', 0.0), ('drawdown', 0.0), ('moneydown', 0.0)]))]), 'Returns': OrderedDict([('rtot', 0.0), ('ravg', 0.0), ('rnorm', 0.0), ('rnorm100', 0.0)]), 'Trade Analysis': AutoOrderedDict([('total', AutoOrderedDict([('total', 0)]))]), 'Final Portfolio Value': 10000.0}
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Backtesting_Analyst (to Backtesting_Analyst_Executor):
#
# The backtesting of the SMACross strategy on Microsoft's stock (MSFT) from January 1, 2023, to January 1, 2024, has been completed. Here are the key results:
#
# - **Starting Portfolio Value:** $10,000.00
# - **Final Portfolio Value:** $10,000.00
# - **Sharpe Ratio:** Not available (the calculation requires a non-zero rate of return or risk-free rate, which might not have been provided or applicable in this case)
# - **Maximum Drawdown:** 0.0% (indicating no drawdown during the backtest period)
# - **Total Number of Trades:** 0
#
# **Analysis:**
# The backtest results indicate that no trades were executed during the specified period using the SMACross strategy with the 50-day short-term SMA and the 200-day long-term SMA. This outcome suggests that the conditions for a buy or sell signal (i.e., the short-term SMA crossing above or below the long-term SMA) were not met during the entire backtest period.
#
# Given these results, it may be necessary to adjust the SMA periods to make the strategy more sensitive to market movements or consider developing a more complex strategy that can capture trading opportunities in different market conditions. Adjusting the SMA periods could involve shortening the time frames to catch more frequent crossovers or exploring other technical indicators that complement the SMA for better signal generation.
#
# Please advise on how you would like to proceed with strategy adjustments or if you wish to explore alternative strategies. TERMINATE
#
# --------------------------------------------------------------------------------
# User_Proxy (to Trade_Strategist):
#
# The backtesting of the SMACross strategy on Microsoft's stock (MSFT) from January 1, 2023, to January 1, 2024, has been completed. Here are the key results:
#
# - **Starting Portfolio Value:** $10,000.00
# - **Final Portfolio Value:** $10,000.00
# - **Sharpe Ratio:** Not available (the calculation requires a non-zero rate of return or risk-free rate, which might not have been provided or applicable in this case)
# - **Maximum Drawdown:** 0.0% (indicating no drawdown during the backtest period)
# - **Total Number of Trades:** 0
#
# **Analysis:**
# The backtest results indicate that no trades were executed during the specified period using the SMACross strategy with the 50-day short-term SMA and the 200-day long-term SMA. This outcome suggests that the conditions for a buy or sell signal (i.e., the short-term SMA crossing above or below the long-term SMA) were not met during the entire backtest period.
#
# Given these results, it may be necessary to adjust the SMA periods to make the strategy more sensitive to market movements or consider developing a more complex strategy that can capture trading opportunities in different market conditions. Adjusting the SMA periods could involve shortening the time frames to catch more frequent crossovers or exploring other technical indicators that complement the SMA for better signal generation.
#
# Please advise on how you would like to proceed with strategy adjustments or if you wish to explore alternative strategies.
#
# --------------------------------------------------------------------------------
# Trade_Strategist (to User_Proxy):
#
# Given the backtest results, it's clear that the initial SMACross strategy parameters did not generate any trading signals for Microsoft's stock within the specified period. This outcome suggests that the market conditions or the chosen SMA periods were not conducive to the strategy's criteria for making trades. To address this, we have a couple of options:
#
# 1. **Adjust the SMA Periods:** We could modify the periods of the short-term and long-term SMAs to make the strategy more sensitive to price movements. Shortening the SMA periods might allow us to capture more frequent crossovers, potentially leading to trading signals. For instance, adjusting the short-term SMA to 20 days and the long-term SMA to 100 days could provide a more responsive strategy to market changes.
#
# 2. **Develop a Custom Strategy:** If adjusting the SMA periods still doesn't yield satisfactory results, or if we aim for a more sophisticated approach, we can develop a custom trading strategy using BackTrader's `Strategy` class. This custom strategy could incorporate additional technical indicators (e.g., RSI, MACD) or include conditions based on volume or price patterns to identify trading opportunities.
#
# Given the need for a more responsive strategy, let's first attempt to adjust the SMA periods and see if that improves the strategy's performance.
#
# **Adjusted Strategy to Backtest:**
# - **Strategy Name:** SMACross
# - **Adjusted Parameters:**
#   - **Short-term SMA period:** 20 days
#   - **Long-term SMA period:** 100 days
# - **Stock Data:** Microsoft (MSFT)
# - **Date Range:** 2023-01-01 to 2024-01-01
#
# This adjustment aims to make the strategy more sensitive to shorter-term market movements, potentially leading to trade signals within the specified period.
#
# Please proceed with backtesting this adjusted SMACross strategy with the new parameters on Microsoft's stock data for the given date range. After reviewing the new backtest results, we can decide whether further adjustments are needed or if we should explore a custom strategy.
#
# --------------------------------------------------------------------------------
# Reflecting strategist's response ...
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Backtesting_Analyst_Executor (to Backtesting_Analyst):
#
# Message from Trade Strategist is as follows:Given the backtest results, it's clear that the initial SMACross strategy parameters did not generate any trading signals for Microsoft's stock within the specified period. This outcome suggests that the market conditions or the chosen SMA periods were not conducive to the strategy's criteria for making trades. To address this, we have a couple of options:
#
# 1. **Adjust the SMA Periods:** We could modify the periods of the short-term and long-term SMAs to make the strategy more sensitive to price movements. Shortening the SMA periods might allow us to capture more frequent crossovers, potentially leading to trading signals. For instance, adjusting the short-term SMA to 20 days and the long-term SMA to 100 days could provide a more responsive strategy to market changes.
#
# 2. **Develop a Custom Strategy:** If adjusting the SMA periods still doesn't yield satisfactory results, or if we aim for a more sophisticated approach, we can develop a custom trading strategy using BackTrader's `Strategy` class. This custom strategy could incorporate additional technical indicators (e.g., RSI, MACD) or include conditions based on volume or price patterns to identify trading opportunities.
#
# Given the need for a more responsive strategy, let's first attempt to adjust the SMA periods and see if that improves the strategy's performance.
#
# **Adjusted Strategy to Backtest:**
# - **Strategy Name:** SMACross
# - **Adjusted Parameters:**
#   - **Short-term SMA period:** 20 days
#   - **Long-term SMA period:** 100 days
# - **Stock Data:** Microsoft (MSFT)
# - **Date Range:** 2023-01-01 to 2024-01-01
#
# This adjustment aims to make the strategy more sensitive to shorter-term market movements, potentially leading to trade signals within the specified period.
#
# Please proceed with backtesting this adjusted SMACross strategy with the new parameters on Microsoft's stock data for the given date range. After reviewing the new backtest results, we can decide whether further adjustments are needed or if we should explore a custom strategy.
#
# If the strategist has completed his work properly, he should have designated a predefined trading strategy or saved a strategy he defined as a Python module. Based on his information, conduct a backtest on the specified stock and strategy, and report your backtesting results back to the strategist.
#
# --------------------------------------------------------------------------------
# Backtesting_Analyst (to Backtesting_Analyst_Executor):
#
# ***** Suggested tool call (call_KTwkx1ZTPh5A5no9xSpSKbh8): back_test *****
# Arguments:
# {"ticker_symbol":"MSFT","start_date":"2023-01-01","end_date":"2024-01-01","strategy":"SMA_CrossOver","params":"{\"fast\": 20, \"slow\": 100}"}
# **************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION back_test...
# [*********************100%%**********************]  1 of 1 completed
# <div id='1fb5a68b-c18b-4469-9c3c-b0a07242ae7e'></div>
# Backtesting_Analyst_Executor (to Backtesting_Analyst):
#
# Backtesting_Analyst_Executor (to Backtesting_Analyst):
#
# ***** Response from calling tool (call_KTwkx1ZTPh5A5no9xSpSKbh8) *****
# Back Test Finished. Results:
# {'Starting Portfolio Value:': 10000.0, 'Sharpe Ratio': OrderedDict([('sharperatio', None)]), 'Drawdown': AutoOrderedDict([('len', 22), ('drawdown', 0.06623825821704232), ('moneydown', 6.647735595703125), ('max', AutoOrderedDict([('len', 22), ('drawdown', 0.166788696210386), ('moneydown', 16.73907470703125)]))]), 'Returns': OrderedDict([('rtot', 0.0029405609969722257), ('ravg', 1.1762243987888904e-05), ('rnorm', 0.0029684827298589547), ('rnorm100', 0.29684827298589544)]), 'Trade Analysis': AutoOrderedDict([('total', AutoOrderedDict([('total', 1), ('open', 1)]))]), 'Final Portfolio Value': 10029.448886873668}
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Backtesting_Analyst (to Backtesting_Analyst_Executor):
#
# The backtest of the adjusted SMACross strategy on Microsoft's stock (MSFT) from January 1, 2023, to January 1, 2024, has been completed. Here are the key results:
#
# - **Starting Portfolio Value:** $10,000.00
# - **Final Portfolio Value:** $10,029.45
# - **Total Trades:** 1 (with 1 currently open)
# - **Sharpe Ratio:** Not available (likely due to insufficient trade data or flat returns)
# - **Maximum Drawdown:** 0.17% (Money down: $16.74)
# - **Total Return:** 0.29%
#
# The strategy executed only one trade during the specified period, indicating a very selective approach based on the adjusted SMA periods (20 days for the short-term SMA and 100 days for the long-term SMA). The minimal activity and slight increase in the portfolio value suggest that while the strategy did engage in trading, it was very conservative, possibly due to the specific SMA settings chosen.
#
# Given the limited trading activity and the modest portfolio increase, further adjustments to the strategy or exploring a custom strategy might be necessary to achieve more significant trading signals and potential returns. This could involve further adjusting the SMA periods or incorporating additional indicators or conditions to enhance the strategy's responsiveness to market movements.
#
# Please advise on the next steps based on these results.
#
# --------------------------------------------------------------------------------
# User_Proxy (to Trade_Strategist):
#
# The backtest of the adjusted SMACross strategy on Microsoft's stock (MSFT) from January 1, 2023, to January 1, 2024, has been completed. Here are the key results:
#
# - **Starting Portfolio Value:** $10,000.00
# - **Final Portfolio Value:** $10,029.45
# - **Total Trades:** 1 (with 1 currently open)
# - **Sharpe Ratio:** Not available (likely due to insufficient trade data or flat returns)
# - **Maximum Drawdown:** 0.17% (Money down: $16.74)
# - **Total Return:** 0.29%
#
# The strategy executed only one trade during the specified period, indicating a very selective approach based on the adjusted SMA periods (20 days for the short-term SMA and 100 days for the long-term SMA). The minimal activity and slight increase in the portfolio value suggest that while the strategy did engage in trading, it was very conservative, possibly due to the specific SMA settings chosen.
#
# Given the limited trading activity and the modest portfolio increase, further adjustments to the strategy or exploring a custom strategy might be necessary to achieve more significant trading signals and potential returns. This could involve further adjusting the SMA periods or incorporating additional indicators or conditions to enhance the strategy's responsiveness to market movements.
#
# Please advise on the next steps based on these results.
#
# --------------------------------------------------------------------------------
# Trade_Strategist (to User_Proxy):
#
# Given the modest results from the adjusted SMACross strategy, it's clear that while we managed to initiate a trade, the strategy's conservative nature led to limited trading activity and only a slight increase in portfolio value. This outcome suggests that further adjustments to the SMA periods alone may not suffice to significantly enhance the strategy's performance. Therefore, it seems appropriate to explore a custom strategy that can incorporate additional indicators or conditions to better capture trading opportunities.
#
# ### Proposed Custom Strategy
#
# For a more dynamic approach, I propose developing a custom strategy that combines multiple technical indicators to generate more robust trading signals. This strategy will not only rely on SMA crossovers but will also incorporate the Relative Strength Index (RSI) and Moving Average Convergence Divergence (MACD) to identify potential buy or sell opportunities based on a combination of momentum and trend-following indicators.
#
# **Custom Strategy Overview:**
# - **Indicators:**
#   - **SMA:** Short-term (20 days) and long-term (100 days) for trend direction.
#   - **RSI:** 14-day period to identify overbought or oversold conditions.
#   - **MACD:** With default settings (fast=12, slow=26, signal=9) to confirm the trend and momentum.
# - **Trading Signals:**
#   - **Buy Signal:** A buy signal is generated when the short-term SMA crosses above the long-term SMA, the RSI is below 70 (to avoid overbought conditions), and the MACD line crosses above the signal line.
#   - **Sell Signal:** A sell signal is generated when the short-term SMA crosses below the long-term SMA, the RSI is above 30 (to avoid oversold conditions), and the MACD line crosses below the signal line.
#
# This strategy aims to leverage the strengths of each indicator, using SMA for trend direction, RSI for market sentiment, and MACD for confirming momentum. By requiring conditions across these indicators to align, the strategy seeks to minimize false signals and enter trades with a higher probability of success.
#
# ### Implementation Plan
#
# 1. **Develop the Custom Strategy:** Code the custom strategy using BackTrader's `Strategy` class, incorporating the logic for the indicators and trading signals as outlined.
# 2. **Backtest the Strategy:** Once the strategy is implemented, backtest it using Microsoft's stock data from 2023-01-01 to 2024-01-01 to evaluate its performance.
# 3. **Analyze Results:** Review the backtest results to assess the strategy's effectiveness, including the number of trades, overall return, drawdown, and other relevant metrics.
#
# Given the direction to proceed with this custom strategy, I will begin the development process, ensuring the strategy is well-coded and aligns with the proposed overview. Once the strategy is ready, I will provide the module path and class name, along with any necessary parameters for backtesting.
#
# Let's proceed with the development of this custom strategy.
# ***** Suggested tool call (call_iMvS6Gv1ihcy7KM3hSKekMem): create_file_with_code *****
# Arguments:
# {"code":"from backtrader import Strategy\nfrom backtrader.indicators import SMA, RSI, MACD\n\nclass CustomSMARsiMacdStrategy(Strategy):\n    params = (('sma_short_period', 20),\n              ('sma_long_period', 100),\n              ('rsi_period', 14),\n              ('macd_fast', 12),\n              ('macd_slow', 26),\n              ('macd_signal', 9))\n\n    def __init__(self):\n        # Indicators for the strategy\n        self.sma_short = SMA(self.data.close, period=self.params.sma_short_period)\n        self.sma_long = SMA(self.data.close, period=self.params.sma_long_period)\n        self.rsi = RSI(self.data, period=self.params.rsi_period)\n        self.macd = MACD(self.data, fastperiod=self.params.macd_fast, slowperiod=self.params.macd_slow, signalperiod=self.params.macd_signal)\n\n        # To keep track of pending orders\n        self.order = None\n\n    def next(self):\n        # Simply log the closing price of the series from the reference\n        self.log('Close, %.2f' % self.data.close[0])\n\n        # Check if an order is pending ... if yes, we cannot send a 2nd one\n        if self.order:\n            return\n\n        # Check if we are in the market\n        if not self.position:\n            # Not yet ... we MIGHT BUY if ...\n            if self.sma_short[0] > self.sma_long[0] and self.rsi[0] < 70 and self.macd[0] > self.macd.signal[0]:\n                # BUY, BUY, BUY!!! (with all possible default parameters)\n                self.log('BUY CREATE, %.2f' % self.data.close[0])\n                self.order = self.buy()\n        else:\n            # Already in the market ... we might sell\n            if self.sma_short[0] < self.sma_long[0] and self.rsi[0] > 30 and self.macd[0] < self.macd.signal[0]:\n                # SELL, SELL, SELL!!! (with all possible default parameters)\n                self.log('SELL CREATE, %.2f' % self.data.close[0])\n                self.order = self.sell()\n\n    def log(self, txt, dt=None):\n        ''' Logging function for this strategy'''\n        dt = dt or self.datas[0].datetime.date(0)\n        print('%s, %s' % (dt.isoformat(), txt))","filename":"custom_sma_rsi_macd_strategy.py"}
# **************************************************************************************
#
# --------------------------------------------------------------------------------
# Reflecting strategist's response ...
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Backtesting_Analyst_Executor (to Backtesting_Analyst):
#
# Message from Trade Strategist is as follows:Given the modest results from the adjusted SMACross strategy, it's clear that while we managed to initiate a trade, the strategy's conservative nature led to limited trading activity and only a slight increase in portfolio value. This outcome suggests that further adjustments to the SMA periods alone may not suffice to significantly enhance the strategy's performance. Therefore, it seems appropriate to explore a custom strategy that can incorporate additional indicators or conditions to better capture trading opportunities.
#
# ### Proposed Custom Strategy
#
# For a more dynamic approach, I propose developing a custom strategy that combines multiple technical indicators to generate more robust trading signals. This strategy will not only rely on SMA crossovers but will also incorporate the Relative Strength Index (RSI) and Moving Average Convergence Divergence (MACD) to identify potential buy or sell opportunities based on a combination of momentum and trend-following indicators.
#
# **Custom Strategy Overview:**
# - **Indicators:**
#   - **SMA:** Short-term (20 days) and long-term (100 days) for trend direction.
#   - **RSI:** 14-day period to identify overbought or oversold conditions.
#   - **MACD:** With default settings (fast=12, slow=26, signal=9) to confirm the trend and momentum.
# - **Trading Signals:**
#   - **Buy Signal:** A buy signal is generated when the short-term SMA crosses above the long-term SMA, the RSI is below 70 (to avoid overbought conditions), and the MACD line crosses above the signal line.
#   - **Sell Signal:** A sell signal is generated when the short-term SMA crosses below the long-term SMA, the RSI is above 30 (to avoid oversold conditions), and the MACD line crosses below the signal line.
#
# This strategy aims to leverage the strengths of each indicator, using SMA for trend direction, RSI for market sentiment, and MACD for confirming momentum. By requiring conditions across these indicators to align, the strategy seeks to minimize false signals and enter trades with a higher probability of success.
#
# ### Implementation Plan
#
# 1. **Develop the Custom Strategy:** Code the custom strategy using BackTrader's `Strategy` class, incorporating the logic for the indicators and trading signals as outlined.
# 2. **Backtest the Strategy:** Once the strategy is implemented, backtest it using Microsoft's stock data from 2023-01-01 to 2024-01-01 to evaluate its performance.
# 3. **Analyze Results:** Review the backtest results to assess the strategy's effectiveness, including the number of trades, overall return, drawdown, and other relevant metrics.
#
# Given the direction to proceed with this custom strategy, I will begin the development process, ensuring the strategy is well-coded and aligns with the proposed overview. Once the strategy is ready, I will provide the module path and class name, along with any necessary parameters for backtesting.
#
# Let's proceed with the development of this custom strategy.
#
# If the strategist has completed his work properly, he should have designated a predefined trading strategy or saved a strategy he defined as a Python module. Based on his information, conduct a backtest on the specified stock and strategy, and report your backtesting results back to the strategist.
#
# --------------------------------------------------------------------------------
# Backtesting_Analyst (to Backtesting_Analyst_Executor):
#
# To proceed with the backtesting of the proposed custom strategy, I will need the module path and class name for the custom strategy that has been developed, as per the implementation plan outlined. This information is crucial to accurately backtest the strategy using the Backtrader library.
#
# Please provide the module path and class name for the custom strategy that incorporates the SMA, RSI, and MACD indicators as described. Additionally, if there are any specific parameters or adjustments made to the default settings of these indicators beyond what was mentioned, kindly include those details as well.
#
# --------------------------------------------------------------------------------
# Backtesting_Analyst_Executor (to Backtesting_Analyst):
#
#
#
# --------------------------------------------------------------------------------
# Backtesting_Analyst (to Backtesting_Analyst_Executor):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# User_Proxy (to Trade_Strategist):
#
#
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[13], line 14
#       5 task = dedent(f"""
#       6     Based on {company}'s stock data from {start_date} to {end_date}, develop a trading strategy that performs well on this stock.
#       7     You can start your research by providing an SMACross strategy as your baseline, then after receiving the backtest analysis, you might adjust parameters to try again
#    (...)
#      10     If it is your own written strategy class, you need to report the corresponding module path and class name, as well as any parameters that the strategy might require.
#      11 """)
#      13 with Cache.disk() as cache:
# ---> 14     user_proxy.initiate_chat(
#      15         recipient=strategist,
#      16         message=task,
#      17         max_turns=10,
#      18         summary_method="last_msg"
#      19     )
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:984, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#     982         if msg2send is None:
#     983             break
# --> 984         self.send(msg2send, recipient, request_reply=True, silent=silent)
#     985 else:
#     986     self._prepare_chat(recipient, clear_history)
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:632, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     630 valid = self._append_oai_message(message, "assistant", recipient)
#     631 if valid:
# --> 632     recipient.receive(message, self, request_reply, silent)
#     633 else:
#     634     raise ValueError(
#     635         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     636     )
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:792, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     790 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     791     return
# --> 792 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     793 if reply is not None:
#     794     self.send(reply, sender, silent=silent)
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1934, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    1932     continue
#    1933 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 1934     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    1935     if final:
#    1936         return reply
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1300, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1298 if messages is None:
#    1299     messages = self._oai_messages[sender]
# -> 1300 extracted_response = self._generate_oai_reply_from_client(
#    1301     client, self._oai_system_message + messages, self.client_cache
#    1302 )
#    1303 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1319, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1316         all_messages.append(message)
#    1318 # TODO: #1143 handle token limit exceeded error
# -> 1319 response = llm_client.create(
#    1320     context=messages[-1].pop("context", None),
#    1321     messages=all_messages,
#    1322     cache=cache,
#    1323 )
#    1324 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1326 if extracted_response is None:
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/autogen/oai/client.py:638, in OpenAIWrapper.create(self, **config)
#     636 try:
#     637     request_ts = get_current_ts()
# --> 638     response = client.create(params)
#     639 except APITimeoutError as err:
#     640     logger.debug(f"config {i} timed out", exc_info=True)
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/autogen/oai/client.py:285, in OpenAIClient.create(self, params)
#     283     params = params.copy()
#     284     params["stream"] = False
# --> 285     response = completions.create(**params)
#     287 return response
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/openai/resources/chat/completions.py:581, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     550 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     551 def create(
#     552     self,
#    (...)
#     579     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     580 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 581     return self._post(
#     582         "/chat/completions",
#     583         body=maybe_transform(
#     584             {
#     585                 "messages": messages,
#     586                 "model": model,
#     587                 "frequency_penalty": frequency_penalty,
#     588                 "function_call": function_call,
#     589                 "functions": functions,
#     590                 "logit_bias": logit_bias,
#     591                 "logprobs": logprobs,
#     592                 "max_tokens": max_tokens,
#     593                 "n": n,
#     594                 "presence_penalty": presence_penalty,
#     595                 "response_format": response_format,
#     596                 "seed": seed,
#     597                 "stop": stop,
#     598                 "stream": stream,
#     599                 "temperature": temperature,
#     600                 "tool_choice": tool_choice,
#     601                 "tools": tools,
#     602                 "top_logprobs": top_logprobs,
#     603                 "top_p": top_p,
#     604                 "user": user,
#     605             },
#     606             completion_create_params.CompletionCreateParams,
#     607         ),
#     608         options=make_request_options(
#     609             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     610         ),
#     611         cast_to=ChatCompletion,
#     612         stream=stream or False,
#     613         stream_cls=Stream[ChatCompletionChunk],
#     614     )
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/openai/_base_client.py:1233, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1219 def post(
#    1220     self,
#    1221     path: str,
#    (...)
#    1228     stream_cls: type[_StreamT] | None = None,
#    1229 ) -> ResponseT | _StreamT:
#    1230     opts = FinalRequestOptions.construct(
#    1231         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1232     )
# -> 1233     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/openai/_base_client.py:922, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     913 def request(
#     914     self,
#     915     cast_to: Type[ResponseT],
#    (...)
#     920     stream_cls: type[_StreamT] | None = None,
#     921 ) -> ResponseT | _StreamT:
# --> 922     return self._request(
#     923         cast_to=cast_to,
#     924         options=options,
#     925         stream=stream,
#     926         stream_cls=stream_cls,
#     927         remaining_retries=remaining_retries,
#     928     )
#
# File /opt/anaconda3/envs/finrobot/lib/python3.10/site-packages/openai/_base_client.py:1013, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010         err.response.read()
#    1012     log.debug("Re-raising status error")
# -> 1013     raise self._make_status_error_from_response(err.response) from None
#    1015 return self._process_response(
#    1016     cast_to=cast_to,
#    1017     options=options,
#    (...)
#    1020     stream_cls=stream_cls,
#    1021 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. The following tool_call_ids did not have response messages: call_iMvS6Gv1ihcy7KM3hSKekMem", 'type': 'invalid_request_error', 'param': 'messages.[7].role', 'code': None}}
